# %%
import config

# %%
import spotipy
import pandas as pd
import json
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
import pprint

# %%
from IPython.display import IFrame

# %%
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
big_playlist_tracks = get_playlist_tracks("Spotify","49G54i94nAqUUsa57pHG4f")

# %%
bp_ids = []
for i in big_playlist_tracks:
    bp_ids.append(i['track']['id'])

# %%
len(bp_ids)
# Out:
# 3461

# %%
chunk_size = 100
#Here comes the code that chops the large list into smaller lists of 100 ids each
bp_ids_chopped = [bp_ids[i:i+chunk_size] for i in range(0,len(bp_ids), 100)]

# %%
len(bp_ids_chopped)
# Out:
# 35

# %%
af_list = []

for i in bp_ids_chopped:
    af_list.extend(sp.audio_features(i))

# %%
af_list
# Out:
# [{'danceability': 0.559,
#   'energy': 0.345,
#   'key': 4,
#   'loudness': -13.496,
#   'mode': 1,
#   'speechiness': 0.0459,
#   'acousticness': 0.0576,
#   'instrumentalness': 0.000105,
#   'liveness': 0.141,
#   'valence': 0.458,
#   'tempo': 84.581,
#   'type': 'audio_features',
#   'id': '3d9DChrdc6BOeFsbrZ3Is0',
#   'uri': 'spotify:track:3d9DChrdc6BOeFsbrZ3Is0',
#   'track_href': 'https://api.spotify.com/v1/tracks/3d9DChrdc6BOeFsbrZ3Is0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3d9DChrdc6BOeFsbrZ3Is0',
#   'duration_ms': 264307,
#   'time_signature': 4},
#  {'danceability': 0.663,
#   'energy': 0.706,
#   'key': 1,
#   'loudness': -4.972,
#   'mode': 0,
#   'speechiness': 0.0383,
#   'acousticness': 0.0654,
#   'instrumentalness': 0,
#   'liveness': 0.115,
#   'valence': 0.474,
#   'tempo': 122.013,
#   'type': 'audio_features',
#   'id': '6sy3LkhNFjJWlaeSMNwQ62',
#   'uri': 'spotify:track:6sy3LkhNFjJWlaeSMNwQ62',
#   'track_href': 'https://api.spotify.com/v1/tracks/6sy3LkhNFjJWlaeSMNwQ62',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6sy3LkhNFjJWlaeSMNwQ62',
#   'duration_ms': 257840,
#   'time_signature': 4},
#  {'danceability': 0.633,
#   'energy': 0.976,
#   'key': 8,
#   'loudness': -5.362,
#   'mode': 1,
#   'speechiness': 0.0519,
#   'acousticness': 0.00281,
#   'instrumentalness': 1.29e-05,
#   'liveness': 0.382,
#   'valence': 0.493,
#   'tempo': 142.027,
#   'type': 'audio_features',
#   'id': '5YJtMNWKe55yr49cyJgxva',
#   'uri': 'spotify:track:5YJtMNWKe55yr49cyJgxva',
#   'track_href': 'https://api.spotify.com/v1/tracks/5YJtMNWKe55yr49cyJgxva',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5YJtMNWKe55yr49cyJgxva',
#   'duration_ms': 197124,
#   'time_signature': 4},
#  {'danceability': 0.749,
#   'energy': 0.745,
#   'key': 2,
#   'loudness': -10.625,
#   'mode': 1,
#   'speechiness': 0.164,
#   'acousticness': 0.000501,
#   'instrumentalness': 0.00403,
#   'liveness': 0.333,
#   'valence': 0.481,
#   'tempo': 101.972,
#   'type': 'audio_features',
#   'id': '27AHAtAirQapVldIm4c9ZX',
#   'uri': 'spotify:track:27AHAtAirQapVldIm4c9ZX',
#   'track_href': 'https://api.spotify.com/v1/tracks/27AHAtAirQapVldIm4c9ZX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/27AHAtAirQapVldIm4c9ZX',
#   'duration_ms': 195107,
#   'time_signature': 4},
#  {'danceability': 0.356,
#   'energy': 0.872,
#   'key': 2,
#   'loudness': -7.837,
#   'mode': 1,
#   'speechiness': 0.068,
#   'acousticness': 0.00417,
#   'instrumentalness': 0.00975,
#   'liveness': 0.0997,
#   'valence': 0.607,
#   'tempo': 166.3,
#   'type': 'audio_features',
#   'id': '5G1sTBGbZT5o4PNRc75RKI',
#   'uri': 'spotify:track:5G1sTBGbZT5o4PNRc75RKI',
#   'track_href': 'https://api.spotify.com/v1/tracks/5G1sTBGbZT5o4PNRc75RKI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5G1sTBGbZT5o4PNRc75RKI',
#   'duration_ms': 193653,
#   'time_signature': 4},
#  {'danceability': 0.743,
#   'energy': 0.446,
#   'key': 4,
#   'loudness': -7.807,
#   'mode': 0,
#   'speechiness': 0.0683,
#   'acousticness': 0.0039,
#   'instrumentalness': 0.118,
#   'liveness': 0.337,
#   'valence': 0.278,
#   'tempo': 123.596,
#   'type': 'audio_features',
#   'id': '3dPQuX8Gs42Y7b454ybpMR',
#   'uri': 'spotify:track:3dPQuX8Gs42Y7b454ybpMR',
#   'track_href': 'https://api.spotify.com/v1/tracks/3dPQuX8Gs42Y7b454ybpMR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3dPQuX8Gs42Y7b454ybpMR',
#   'duration_ms': 232107,
#   'time_signature': 4},
#  {'danceability': 0.708,
#   'energy': 0.462,
#   'key': 6,
#   'loudness': -6.419,
#   'mode': 1,
#   'speechiness': 0.0339,
#   'acousticness': 0.352,
#   'instrumentalness': 8.34e-06,
#   'liveness': 0.112,
#   'valence': 0.495,
#   'tempo': 99.988,
#   'type': 'audio_features',
#   'id': '3qiDkKNPtSSgJZEpoC74M3',
#   'uri': 'spotify:track:3qiDkKNPtSSgJZEpoC74M3',
#   'track_href': 'https://api.spotify.com/v1/tracks/3qiDkKNPtSSgJZEpoC74M3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3qiDkKNPtSSgJZEpoC74M3',
#   'duration_ms': 219680,
#   'time_signature': 4},
#  {'danceability': 0.71,
#   'energy': 0.698,
#   'key': 2,
#   'loudness': -5.797,
#   'mode': 1,
#   'speechiness': 0.0332,
#   'acousticness': 0.0697,
#   'instrumentalness': 0,
#   'liveness': 0.478,
#   'valence': 0.852,
#   'tempo': 104.007,
#   'type': 'audio_features',
#   'id': '4asjU3sDnn3002bTJIg2vZ',
#   'uri': 'spotify:track:4asjU3sDnn3002bTJIg2vZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/4asjU3sDnn3002bTJIg2vZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4asjU3sDnn3002bTJIg2vZ',
#   'duration_ms': 264813,
#   'time_signature': 4},
#  {'danceability': 0.813,
#   'energy': 0.728,
#   'key': 4,
#   'loudness': -5.795,
#   'mode': 0,
#   'speechiness': 0.0681,
#   'acousticness': 0.0901,
#   'instrumentalness': 0.000363,
#   'liveness': 0.115,
#   'valence': 0.96,
#   'tempo': 128.098,
#   'type': 'audio_features',
#   'id': '4k15blneKWudA2gBmlWFIW',
#   'uri': 'spotify:track:4k15blneKWudA2gBmlWFIW',
#   'track_href': 'https://api.spotify.com/v1/tracks/4k15blneKWudA2gBmlWFIW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4k15blneKWudA2gBmlWFIW',
#   'duration_ms': 235560,
#   'time_signature': 4},
#  {'danceability': 0.517,
#   'energy': 0.711,
#   'key': 6,
#   'loudness': -5.84,
#   'mode': 0,
#   'speechiness': 0.0627,
#   'acousticness': 0.000763,
#   'instrumentalness': 7.15e-06,
#   'liveness': 0.568,
#   'valence': 0.582,
#   'tempo': 108.846,
#   'type': 'audio_features',
#   'id': '3C542UknrX76XSRXTyQ1Qg',
#   'uri': 'spotify:track:3C542UknrX76XSRXTyQ1Qg',
#   'track_href': 'https://api.spotify.com/v1/tracks/3C542UknrX76XSRXTyQ1Qg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3C542UknrX76XSRXTyQ1Qg',
#   'duration_ms': 211336,
#   'time_signature': 4},
#  {'danceability': 0.295,
#   'energy': 0.94,
#   'key': 11,
#   'loudness': -5.247,
#   'mode': 1,
#   'speechiness': 0.0449,
#   'acousticness': 0.00021,
#   'instrumentalness': 0.00106,
#   'liveness': 0.276,
#   'valence': 0.58,
#   'tempo': 186.186,
#   'type': 'audio_features',
#   'id': '4nzyOwogJuWn1s6QuGFZ6w',
#   'uri': 'spotify:track:4nzyOwogJuWn1s6QuGFZ6w',
#   'track_href': 'https://api.spotify.com/v1/tracks/4nzyOwogJuWn1s6QuGFZ6w',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4nzyOwogJuWn1s6QuGFZ6w',
#   'duration_ms': 204293,
#   'time_signature': 3},
#  {'danceability': 0.438,
#   'energy': 0.938,
#   'key': 6,
#   'loudness': -5.611,
#   'mode': 0,
#   'speechiness': 0.094,
#   'acousticness': 0.00842,
#   'instrumentalness': 1.08e-06,
#   'liveness': 0.806,
#   'valence': 0.584,
#   'tempo': 160.212,
#   'type': 'audio_features',
#   'id': '61XspFITuKmAlYdQacNCbF',
#   'uri': 'spotify:track:61XspFITuKmAlYdQacNCbF',
#   'track_href': 'https://api.spotify.com/v1/tracks/61XspFITuKmAlYdQacNCbF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/61XspFITuKmAlYdQacNCbF',
#   'duration_ms': 181493,
#   'time_signature': 4},
#  {'danceability': 0.681,
#   'energy': 0.706,
#   'key': 9,
#   'loudness': -8.359,
#   'mode': 1,
#   'speechiness': 0.0392,
#   'acousticness': 0.151,
#   'instrumentalness': 2.35e-05,
#   'liveness': 0.114,
#   'valence': 0.971,
#   'tempo': 102.38,
#   'type': 'audio_features',
#   'id': '7zJi6HnUzxo2J4La1yTFj3',
#   'uri': 'spotify:track:7zJi6HnUzxo2J4La1yTFj3',
#   'track_href': 'https://api.spotify.com/v1/tracks/7zJi6HnUzxo2J4La1yTFj3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7zJi6HnUzxo2J4La1yTFj3',
#   'duration_ms': 192067,
#   'time_signature': 4},
#  {'danceability': 0.725,
#   'energy': 0.747,
#   'key': 11,
#   'loudness': -5.545,
#   'mode': 1,
#   'speechiness': 0.0876,
#   'acousticness': 0.0272,
#   'instrumentalness': 0.0468,
#   'liveness': 0.104,
#   'valence': 0.38,
#   'tempo': 132.921,
#   'type': 'audio_features',
#   'id': '4yffABDkB5A9flvr9vQFck',
#   'uri': 'spotify:track:4yffABDkB5A9flvr9vQFck',
#   'track_href': 'https://api.spotify.com/v1/tracks/4yffABDkB5A9flvr9vQFck',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4yffABDkB5A9flvr9vQFck',
#   'duration_ms': 191956,
#   'time_signature': 4},
#  {'danceability': 0.652,
#   'energy': 0.707,
#   'key': 4,
#   'loudness': -4.552,
#   'mode': 1,
#   'speechiness': 0.0297,
#   'acousticness': 0.000122,
#   'instrumentalness': 2.78e-06,
#   'liveness': 0.485,
#   'valence': 0.656,
#   'tempo': 121.998,
#   'type': 'audio_features',
#   'id': '0nDvTmQlCcJMIIrAzdy7z3',
#   'uri': 'spotify:track:0nDvTmQlCcJMIIrAzdy7z3',
#   'track_href': 'https://api.spotify.com/v1/tracks/0nDvTmQlCcJMIIrAzdy7z3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0nDvTmQlCcJMIIrAzdy7z3',
#   'duration_ms': 207493,
#   'time_signature': 4},
#  {'danceability': 0.509,
#   'energy': 0.584,
#   'key': 0,
#   'loudness': -4.907,
#   'mode': 1,
#   'speechiness': 0.057,
#   'acousticness': 0.0368,
#   'instrumentalness': 9.96e-05,
#   'liveness': 0.384,
#   'valence': 0.685,
#   'tempo': 170.411,
#   'type': 'audio_features',
#   'id': '6y20BV5L33R8YXM0YuI38N',
#   'uri': 'spotify:track:6y20BV5L33R8YXM0YuI38N',
#   'track_href': 'https://api.spotify.com/v1/tracks/6y20BV5L33R8YXM0YuI38N',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6y20BV5L33R8YXM0YuI38N',
#   'duration_ms': 278747,
#   'time_signature': 4},
#  {'danceability': 0.431,
#   'energy': 0.617,
#   'key': 0,
#   'loudness': -3.125,
#   'mode': 0,
#   'speechiness': 0.0496,
#   'acousticness': 0.53,
#   'instrumentalness': 0.00553,
#   'liveness': 0.122,
#   'valence': 0.873,
#   'tempo': 98.167,
#   'type': 'audio_features',
#   'id': '5GZq8P4Iy2smHngL07Pcuo',
#   'uri': 'spotify:track:5GZq8P4Iy2smHngL07Pcuo',
#   'track_href': 'https://api.spotify.com/v1/tracks/5GZq8P4Iy2smHngL07Pcuo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5GZq8P4Iy2smHngL07Pcuo',
#   'duration_ms': 128893,
#   'time_signature': 4},
#  {'danceability': 0.219,
#   'energy': 0.952,
#   'key': 2,
#   'loudness': -3.621,
#   'mode': 1,
#   'speechiness': 0.176,
#   'acousticness': 5.1e-05,
#   'instrumentalness': 0.0989,
#   'liveness': 0.157,
#   'valence': 0.172,
#   'tempo': 112.886,
#   'type': 'audio_features',
#   'id': '3CkjLJYnnyOtGk4Jx4iYS4',
#   'uri': 'spotify:track:3CkjLJYnnyOtGk4Jx4iYS4',
#   'track_href': 'https://api.spotify.com/v1/tracks/3CkjLJYnnyOtGk4Jx4iYS4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3CkjLJYnnyOtGk4Jx4iYS4',
#   'duration_ms': 176307,
#   'time_signature': 1},
#  {'danceability': 0.452,
#   'energy': 0.873,
#   'key': 9,
#   'loudness': -4.867,
#   'mode': 1,
#   'speechiness': 0.0613,
#   'acousticness': 0.000519,
#   'instrumentalness': 0,
#   'liveness': 0.0592,
#   'valence': 0.433,
#   'tempo': 80.473,
#   'type': 'audio_features',
#   'id': '1TDk2Jmi4dVZhm2dum3Jim',
#   'uri': 'spotify:track:1TDk2Jmi4dVZhm2dum3Jim',
#   'track_href': 'https://api.spotify.com/v1/tracks/1TDk2Jmi4dVZhm2dum3Jim',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1TDk2Jmi4dVZhm2dum3Jim',
#   'duration_ms': 222027,
#   'time_signature': 4},
#  {'danceability': 0.515,
#   'energy': 0.864,
#   'key': 2,
#   'loudness': -5.384,
#   'mode': 1,
#   'speechiness': 0.0478,
#   'acousticness': 0.00182,
#   'instrumentalness': 7.32e-05,
#   'liveness': 0.108,
#   'valence': 0.232,
#   'tempo': 153.966,
#   'type': 'audio_features',
#   'id': '77eRSoQbDt4qHlAhUqovmy',
#   'uri': 'spotify:track:77eRSoQbDt4qHlAhUqovmy',
#   'track_href': 'https://api.spotify.com/v1/tracks/77eRSoQbDt4qHlAhUqovmy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/77eRSoQbDt4qHlAhUqovmy',
#   'duration_ms': 283160,
#   'time_signature': 4},
#  {'danceability': 0.603,
#   'energy': 0.82,
#   'key': 4,
#   'loudness': -6.145,
#   'mode': 0,
#   'speechiness': 0.051,
#   'acousticness': 0.000506,
#   'instrumentalness': 2.34e-06,
#   'liveness': 0.13,
#   'valence': 0.408,
#   'tempo': 103.907,
#   'type': 'audio_features',
#   'id': '6VNRBXV7lQz9VAHhsfYkrE',
#   'uri': 'spotify:track:6VNRBXV7lQz9VAHhsfYkrE',
#   'track_href': 'https://api.spotify.com/v1/tracks/6VNRBXV7lQz9VAHhsfYkrE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6VNRBXV7lQz9VAHhsfYkrE',
#   'duration_ms': 260181,
#   'time_signature': 4},
#  {'danceability': 0.355,
#   'energy': 0.867,
#   'key': 2,
#   'loudness': -3.144,
#   'mode': 1,
#   'speechiness': 0.0738,
#   'acousticness': 0.00664,
#   'instrumentalness': 0.554,
#   'liveness': 0.323,
#   'valence': 0.295,
#   'tempo': 142.849,
#   'type': 'audio_features',
#   'id': '4RvmQ5qbP5PxgJD0BN4EZK',
#   'uri': 'spotify:track:4RvmQ5qbP5PxgJD0BN4EZK',
#   'track_href': 'https://api.spotify.com/v1/tracks/4RvmQ5qbP5PxgJD0BN4EZK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4RvmQ5qbP5PxgJD0BN4EZK',
#   'duration_ms': 180133,
#   'time_signature': 4},
#  {'danceability': 0.487,
#   'energy': 0.898,
#   'key': 5,
#   'loudness': -4.436,
#   'mode': 1,
#   'speechiness': 0.038,
#   'acousticness': 0.00305,
#   'instrumentalness': 0,
#   'liveness': 0.26,
#   'valence': 0.597,
#   'tempo': 135.331,
#   'type': 'audio_features',
#   'id': '429IbFR4yp2J81CeTwF5iY',
#   'uri': 'spotify:track:429IbFR4yp2J81CeTwF5iY',
#   'track_href': 'https://api.spotify.com/v1/tracks/429IbFR4yp2J81CeTwF5iY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/429IbFR4yp2J81CeTwF5iY',
#   'duration_ms': 220027,
#   'time_signature': 4},
#  {'danceability': 0.543,
#   'energy': 0.696,
#   'key': 7,
#   'loudness': -4.572,
#   'mode': 1,
#   'speechiness': 0.0426,
#   'acousticness': 0.601,
#   'instrumentalness': 0.215,
#   'liveness': 0.384,
#   'valence': 0.849,
#   'tempo': 92.15,
#   'type': 'audio_features',
#   'id': '3xRzUblYGZhVs52fMjii7R',
#   'uri': 'spotify:track:3xRzUblYGZhVs52fMjii7R',
#   'track_href': 'https://api.spotify.com/v1/tracks/3xRzUblYGZhVs52fMjii7R',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3xRzUblYGZhVs52fMjii7R',
#   'duration_ms': 253747,
#   'time_signature': 4},
#  {'danceability': 0.481,
#   'energy': 0.94,
#   'key': 7,
#   'loudness': -5.204,
#   'mode': 1,
#   'speechiness': 0.066,
#   'acousticness': 0.000891,
#   'instrumentalness': 0,
#   'liveness': 0.0939,
#   'valence': 0.66,
#   'tempo': 96.493,
#   'type': 'audio_features',
#   'id': '3mNecsYFb6LQg7822DPXCP',
#   'uri': 'spotify:track:3mNecsYFb6LQg7822DPXCP',
#   'track_href': 'https://api.spotify.com/v1/tracks/3mNecsYFb6LQg7822DPXCP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3mNecsYFb6LQg7822DPXCP',
#   'duration_ms': 189333,
#   'time_signature': 4},
#  {'danceability': 0.519,
#   'energy': 0.666,
#   'key': 1,
#   'loudness': -9.732,
#   'mode': 1,
#   'speechiness': 0.0645,
#   'acousticness': 0.101,
#   'instrumentalness': 0.346,
#   'liveness': 0.118,
#   'valence': 0.274,
#   'tempo': 146.467,
#   'type': 'audio_features',
#   'id': '5HkLVhdVOifwVzQhuh51dL',
#   'uri': 'spotify:track:5HkLVhdVOifwVzQhuh51dL',
#   'track_href': 'https://api.spotify.com/v1/tracks/5HkLVhdVOifwVzQhuh51dL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5HkLVhdVOifwVzQhuh51dL',
#   'duration_ms': 141160,
#   'time_signature': 4},
#  {'danceability': 0.64,
#   'energy': 0.864,
#   'key': 7,
#   'loudness': -6.576,
#   'mode': 1,
#   'speechiness': 0.0314,
#   'acousticness': 0.00832,
#   'instrumentalness': 0,
#   'liveness': 0.123,
#   'valence': 0.701,
#   'tempo': 102.026,
#   'type': 'audio_features',
#   'id': '42et6fnHCw1HIPSrdPprMl',
#   'uri': 'spotify:track:42et6fnHCw1HIPSrdPprMl',
#   'track_href': 'https://api.spotify.com/v1/tracks/42et6fnHCw1HIPSrdPprMl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/42et6fnHCw1HIPSrdPprMl',
#   'duration_ms': 268360,
#   'time_signature': 4},
#  {'danceability': 0.526,
#   'energy': 0.862,
#   'key': 2,
#   'loudness': -6.003,
#   'mode': 1,
#   'speechiness': 0.0905,
#   'acousticness': 0.0144,
#   'instrumentalness': 0.0597,
#   'liveness': 0.229,
#   'valence': 0.528,
#   'tempo': 90.052,
#   'type': 'audio_features',
#   'id': '5cKhVlFn0Kuq68V56lSLvW',
#   'uri': 'spotify:track:5cKhVlFn0Kuq68V56lSLvW',
#   'track_href': 'https://api.spotify.com/v1/tracks/5cKhVlFn0Kuq68V56lSLvW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5cKhVlFn0Kuq68V56lSLvW',
#   'duration_ms': 195200,
#   'time_signature': 4},
#  {'danceability': 0.53,
#   'energy': 0.707,
#   'key': 10,
#   'loudness': -5.516,
#   'mode': 1,
#   'speechiness': 0.203,
#   'acousticness': 0.104,
#   'instrumentalness': 0,
#   'liveness': 0.105,
#   'valence': 0.696,
#   'tempo': 109.827,
#   'type': 'audio_features',
#   'id': '7gevvAspxft2qQmcvJjNBH',
#   'uri': 'spotify:track:7gevvAspxft2qQmcvJjNBH',
#   'track_href': 'https://api.spotify.com/v1/tracks/7gevvAspxft2qQmcvJjNBH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7gevvAspxft2qQmcvJjNBH',
#   'duration_ms': 203453,
#   'time_signature': 4},
#  {'danceability': 0.765,
#   'energy': 0.516,
#   'key': 7,
#   'loudness': -12.099,
#   'mode': 1,
#   'speechiness': 0.0334,
#   'acousticness': 0.167,
#   'instrumentalness': 0,
#   'liveness': 0.0723,
#   'valence': 0.936,
#   'tempo': 115.248,
#   'type': 'audio_features',
#   'id': '0i7O5MtSTXvR4BEY7stpjF',
#   'uri': 'spotify:track:0i7O5MtSTXvR4BEY7stpjF',
#   'track_href': 'https://api.spotify.com/v1/tracks/0i7O5MtSTXvR4BEY7stpjF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0i7O5MtSTXvR4BEY7stpjF',
#   'duration_ms': 231800,
#   'time_signature': 4},
#  {'danceability': 0.677,
#   'energy': 0.871,
#   'key': 1,
#   'loudness': -7.997,
#   'mode': 1,
#   'speechiness': 0.0281,
#   'acousticness': 0.284,
#   'instrumentalness': 3.02e-05,
#   'liveness': 0.405,
#   'valence': 0.898,
#   'tempo': 98.446,
#   'type': 'audio_features',
#   'id': '5YLVhkyMsAuYKOKihHJo21',
#   'uri': 'spotify:track:5YLVhkyMsAuYKOKihHJo21',
#   'track_href': 'https://api.spotify.com/v1/tracks/5YLVhkyMsAuYKOKihHJo21',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5YLVhkyMsAuYKOKihHJo21',
#   'duration_ms': 268893,
#   'time_signature': 4},
#  {'danceability': 0.633,
#   'energy': 0.933,
#   'key': 9,
#   'loudness': -2.795,
#   'mode': 1,
#   'speechiness': 0.0821,
#   'acousticness': 0.125,
#   'instrumentalness': 0.671,
#   'liveness': 0.0514,
#   'valence': 0.611,
#   'tempo': 107.483,
#   'type': 'audio_features',
#   'id': '4z2fha9ZhIjU2PisUO1v1v',
#   'uri': 'spotify:track:4z2fha9ZhIjU2PisUO1v1v',
#   'track_href': 'https://api.spotify.com/v1/tracks/4z2fha9ZhIjU2PisUO1v1v',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4z2fha9ZhIjU2PisUO1v1v',
#   'duration_ms': 210907,
#   'time_signature': 4},
#  {'danceability': 0.67,
#   'energy': 0.595,
#   'key': 1,
#   'loudness': -18.148,
#   'mode': 1,
#   'speechiness': 0.123,
#   'acousticness': 0.581,
#   'instrumentalness': 0,
#   'liveness': 0.158,
#   'valence': 0.852,
#   'tempo': 116.421,
#   'type': 'audio_features',
#   'id': '2W93VKSfWw1evp7FSbHNd1',
#   'uri': 'spotify:track:2W93VKSfWw1evp7FSbHNd1',
#   'track_href': 'https://api.spotify.com/v1/tracks/2W93VKSfWw1evp7FSbHNd1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2W93VKSfWw1evp7FSbHNd1',
#   'duration_ms': 175253,
#   'time_signature': 4},
#  {'danceability': 0.676,
#   'energy': 0.828,
#   'key': 0,
#   'loudness': -5.799,
#   'mode': 1,
#   'speechiness': 0.0454,
#   'acousticness': 0.0242,
#   'instrumentalness': 0.0105,
#   'liveness': 0.364,
#   'valence': 0.669,
#   'tempo': 122.228,
#   'type': 'audio_features',
#   'id': '2SDx0PooHZI1SQKR0y44bs',
#   'uri': 'spotify:track:2SDx0PooHZI1SQKR0y44bs',
#   'track_href': 'https://api.spotify.com/v1/tracks/2SDx0PooHZI1SQKR0y44bs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2SDx0PooHZI1SQKR0y44bs',
#   'duration_ms': 187733,
#   'time_signature': 4},
#  {'danceability': 0.666,
#   'energy': 0.791,
#   'key': 6,
#   'loudness': -5.125,
#   'mode': 0,
#   'speechiness': 0.0279,
#   'acousticness': 0.0156,
#   'instrumentalness': 0.00509,
#   'liveness': 0.0938,
#   'valence': 0.855,
#   'tempo': 121.98,
#   'type': 'audio_features',
#   'id': '3us8wMbZzKbIGXVR6LJ28A',
#   'uri': 'spotify:track:3us8wMbZzKbIGXVR6LJ28A',
#   'track_href': 'https://api.spotify.com/v1/tracks/3us8wMbZzKbIGXVR6LJ28A',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3us8wMbZzKbIGXVR6LJ28A',
#   'duration_ms': 225267,
#   'time_signature': 4},
#  {'danceability': 0.309,
#   'energy': 0.649,
#   'key': 7,
#   'loudness': -8.994,
#   'mode': 1,
#   'speechiness': 0.035,
#   'acousticness': 0.0158,
#   'instrumentalness': 0.00591,
#   'liveness': 0.367,
#   'valence': 0.312,
#   'tempo': 166.915,
#   'type': 'audio_features',
#   'id': '7EZC6E7UjZe63f1jRmkWxt',
#   'uri': 'spotify:track:7EZC6E7UjZe63f1jRmkWxt',
#   'track_href': 'https://api.spotify.com/v1/tracks/7EZC6E7UjZe63f1jRmkWxt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7EZC6E7UjZe63f1jRmkWxt',
#   'duration_ms': 306440,
#   'time_signature': 4},
#  {'danceability': 0.468,
#   'energy': 0.692,
#   'key': 2,
#   'loudness': -4.015,
#   'mode': 1,
#   'speechiness': 0.0295,
#   'acousticness': 0.0202,
#   'instrumentalness': 2.39e-06,
#   'liveness': 0.523,
#   'valence': 0.561,
#   'tempo': 78.009,
#   'type': 'audio_features',
#   'id': '3omXshBamrREltcf24gYDC',
#   'uri': 'spotify:track:3omXshBamrREltcf24gYDC',
#   'track_href': 'https://api.spotify.com/v1/tracks/3omXshBamrREltcf24gYDC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3omXshBamrREltcf24gYDC',
#   'duration_ms': 200360,
#   'time_signature': 4},
#  {'danceability': 0.585,
#   'energy': 0.776,
#   'key': 5,
#   'loudness': -5.898,
#   'mode': 1,
#   'speechiness': 0.0459,
#   'acousticness': 0.0572,
#   'instrumentalness': 7.74e-06,
#   'liveness': 0.3,
#   'valence': 0.427,
#   'tempo': 77.987,
#   'type': 'audio_features',
#   'id': '5xEM5hIgJ1jjgcEBfpkt2F',
#   'uri': 'spotify:track:5xEM5hIgJ1jjgcEBfpkt2F',
#   'track_href': 'https://api.spotify.com/v1/tracks/5xEM5hIgJ1jjgcEBfpkt2F',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5xEM5hIgJ1jjgcEBfpkt2F',
#   'duration_ms': 244507,
#   'time_signature': 4},
#  {'danceability': 0.43,
#   'energy': 0.665,
#   'key': 4,
#   'loudness': -9.681,
#   'mode': 1,
#   'speechiness': 0.139,
#   'acousticness': 0.406,
#   'instrumentalness': 0.000108,
#   'liveness': 0.409,
#   'valence': 0.542,
#   'tempo': 160.859,
#   'type': 'audio_features',
#   'id': '3V3MQOlQqq8SZ7BcoN4QCn',
#   'uri': 'spotify:track:3V3MQOlQqq8SZ7BcoN4QCn',
#   'track_href': 'https://api.spotify.com/v1/tracks/3V3MQOlQqq8SZ7BcoN4QCn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3V3MQOlQqq8SZ7BcoN4QCn',
#   'duration_ms': 266240,
#   'time_signature': 4},
#  {'danceability': 0.505,
#   'energy': 0.833,
#   'key': 0,
#   'loudness': -4.632,
#   'mode': 1,
#   'speechiness': 0.0475,
#   'acousticness': 0.00772,
#   'instrumentalness': 7.9e-05,
#   'liveness': 0.069,
#   'valence': 0.565,
#   'tempo': 130.121,
#   'type': 'audio_features',
#   'id': '5lN1EH25gdiqT1SFALMAq1',
#   'uri': 'spotify:track:5lN1EH25gdiqT1SFALMAq1',
#   'track_href': 'https://api.spotify.com/v1/tracks/5lN1EH25gdiqT1SFALMAq1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5lN1EH25gdiqT1SFALMAq1',
#   'duration_ms': 224333,
#   'time_signature': 4},
#  {'danceability': 0.62,
#   'energy': 0.573,
#   'key': 0,
#   'loudness': -11.893,
#   'mode': 1,
#   'speechiness': 0.0423,
#   'acousticness': 0.271,
#   'instrumentalness': 0,
#   'liveness': 0.0607,
#   'valence': 0.897,
#   'tempo': 81.548,
#   'type': 'audio_features',
#   'id': '0ikz6tENMONtK6qGkOrU3c',
#   'uri': 'spotify:track:0ikz6tENMONtK6qGkOrU3c',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ikz6tENMONtK6qGkOrU3c',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ikz6tENMONtK6qGkOrU3c',
#   'duration_ms': 231333,
#   'time_signature': 4},
#  {'danceability': 0.532,
#   'energy': 0.783,
#   'key': 2,
#   'loudness': -5.697,
#   'mode': 1,
#   'speechiness': 0.0523,
#   'acousticness': 0.0038,
#   'instrumentalness': 0.0012,
#   'liveness': 0.161,
#   'valence': 0.643,
#   'tempo': 124.08,
#   'type': 'audio_features',
#   'id': '0nrRP2bk19rLc0orkWPQk2',
#   'uri': 'spotify:track:0nrRP2bk19rLc0orkWPQk2',
#   'track_href': 'https://api.spotify.com/v1/tracks/0nrRP2bk19rLc0orkWPQk2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0nrRP2bk19rLc0orkWPQk2',
#   'duration_ms': 247427,
#   'time_signature': 4},
#  {'danceability': 0.331,
#   'energy': 0.943,
#   'key': 4,
#   'loudness': -3.188,
#   'mode': 0,
#   'speechiness': 0.0698,
#   'acousticness': 0.00721,
#   'instrumentalness': 2.06e-06,
#   'liveness': 0.242,
#   'valence': 0.296,
#   'tempo': 94.612,
#   'type': 'audio_features',
#   'id': '0COqiPhxzoWICwFCS4eZcp',
#   'uri': 'spotify:track:0COqiPhxzoWICwFCS4eZcp',
#   'track_href': 'https://api.spotify.com/v1/tracks/0COqiPhxzoWICwFCS4eZcp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0COqiPhxzoWICwFCS4eZcp',
#   'duration_ms': 235893,
#   'time_signature': 4},
#  {'danceability': 0.623,
#   'energy': 0.886,
#   'key': 1,
#   'loudness': -3.044,
#   'mode': 1,
#   'speechiness': 0.0404,
#   'acousticness': 0.0245,
#   'instrumentalness': 0,
#   'liveness': 0.247,
#   'valence': 0.709,
#   'tempo': 92.021,
#   'type': 'audio_features',
#   'id': '6L3VWDPDTQkQFkqvmpAUMU',
#   'uri': 'spotify:track:6L3VWDPDTQkQFkqvmpAUMU',
#   'track_href': 'https://api.spotify.com/v1/tracks/6L3VWDPDTQkQFkqvmpAUMU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6L3VWDPDTQkQFkqvmpAUMU',
#   'duration_ms': 228467,
#   'time_signature': 4},
#  {'danceability': 0.671,
#   'energy': 0.683,
#   'key': 7,
#   'loudness': -5.271,
#   'mode': 1,
#   'speechiness': 0.0965,
#   'acousticness': 0.135,
#   'instrumentalness': 0.00107,
#   'liveness': 0.0534,
#   'valence': 0.809,
#   'tempo': 164.943,
#   'type': 'audio_features',
#   'id': '4ZifmvedzdccUUuiGDAbTU',
#   'uri': 'spotify:track:4ZifmvedzdccUUuiGDAbTU',
#   'track_href': 'https://api.spotify.com/v1/tracks/4ZifmvedzdccUUuiGDAbTU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ZifmvedzdccUUuiGDAbTU',
#   'duration_ms': 193369,
#   'time_signature': 4},
#  {'danceability': 0.415,
#   'energy': 0.554,
#   'key': 7,
#   'loudness': -10.839,
#   'mode': 0,
#   'speechiness': 0.0334,
#   'acousticness': 0.00541,
#   'instrumentalness': 0.00202,
#   'liveness': 0.155,
#   'valence': 0.163,
#   'tempo': 120.318,
#   'type': 'audio_features',
#   'id': '4wzt5Rrk3W98pHXAqutuJw',
#   'uri': 'spotify:track:4wzt5Rrk3W98pHXAqutuJw',
#   'track_href': 'https://api.spotify.com/v1/tracks/4wzt5Rrk3W98pHXAqutuJw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4wzt5Rrk3W98pHXAqutuJw',
#   'duration_ms': 311292,
#   'time_signature': 4},
#  {'danceability': 0.71,
#   'energy': 0.799,
#   'key': 6,
#   'loudness': -4.897,
#   'mode': 1,
#   'speechiness': 0.0328,
#   'acousticness': 0.22,
#   'instrumentalness': 0.000602,
#   'liveness': 0.349,
#   'valence': 0.725,
#   'tempo': 120.372,
#   'type': 'audio_features',
#   'id': '4y1LsJpmMti1PfRQV9AWWe',
#   'uri': 'spotify:track:4y1LsJpmMti1PfRQV9AWWe',
#   'track_href': 'https://api.spotify.com/v1/tracks/4y1LsJpmMti1PfRQV9AWWe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4y1LsJpmMti1PfRQV9AWWe',
#   'duration_ms': 238267,
#   'time_signature': 4},
#  {'danceability': 0.685,
#   'energy': 0.571,
#   'key': 2,
#   'loudness': -11.623,
#   'mode': 1,
#   'speechiness': 0.0299,
#   'acousticness': 0.335,
#   'instrumentalness': 2.38e-06,
#   'liveness': 0.214,
#   'valence': 0.869,
#   'tempo': 121.737,
#   'type': 'audio_features',
#   'id': '7Di7t9yGoxdZRLAt5a4pi0',
#   'uri': 'spotify:track:7Di7t9yGoxdZRLAt5a4pi0',
#   'track_href': 'https://api.spotify.com/v1/tracks/7Di7t9yGoxdZRLAt5a4pi0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7Di7t9yGoxdZRLAt5a4pi0',
#   'duration_ms': 184173,
#   'time_signature': 4},
#  {'danceability': 0.643,
#   'energy': 0.802,
#   'key': 6,
#   'loudness': -4.92,
#   'mode': 1,
#   'speechiness': 0.0227,
#   'acousticness': 0.0299,
#   'instrumentalness': 0,
#   'liveness': 0.0719,
#   'valence': 0.53,
#   'tempo': 95.99,
#   'type': 'audio_features',
#   'id': '3X7uFMzJrEE0sxn62qd8Ch',
#   'uri': 'spotify:track:3X7uFMzJrEE0sxn62qd8Ch',
#   'track_href': 'https://api.spotify.com/v1/tracks/3X7uFMzJrEE0sxn62qd8Ch',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3X7uFMzJrEE0sxn62qd8Ch',
#   'duration_ms': 270333,
#   'time_signature': 4},
#  {'danceability': 0.521,
#   'energy': 0.233,
#   'key': 7,
#   'loudness': -13.683,
#   'mode': 1,
#   'speechiness': 0.0254,
#   'acousticness': 0.635,
#   'instrumentalness': 0,
#   'liveness': 0.245,
#   'valence': 0.4,
#   'tempo': 78.93,
#   'type': 'audio_features',
#   'id': '5g3ZD7PmrEQlQZKDW91yGG',
#   'uri': 'spotify:track:5g3ZD7PmrEQlQZKDW91yGG',
#   'track_href': 'https://api.spotify.com/v1/tracks/5g3ZD7PmrEQlQZKDW91yGG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5g3ZD7PmrEQlQZKDW91yGG',
#   'duration_ms': 235667,
#   'time_signature': 3},
#  {'danceability': 0.482,
#   'energy': 0.742,
#   'key': 6,
#   'loudness': -8.108,
#   'mode': 1,
#   'speechiness': 0.0269,
#   'acousticness': 0.0514,
#   'instrumentalness': 0,
#   'liveness': 0.898,
#   'valence': 0.561,
#   'tempo': 96.133,
#   'type': 'audio_features',
#   'id': '77Oww6V7jooOd7aNEMnFJ3',
#   'uri': 'spotify:track:77Oww6V7jooOd7aNEMnFJ3',
#   'track_href': 'https://api.spotify.com/v1/tracks/77Oww6V7jooOd7aNEMnFJ3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/77Oww6V7jooOd7aNEMnFJ3',
#   'duration_ms': 251733,
#   'time_signature': 4},
#  {'danceability': 0.394,
#   'energy': 0.547,
#   'key': 2,
#   'loudness': -9.276,
#   'mode': 1,
#   'speechiness': 0.0383,
#   'acousticness': 0.436,
#   'instrumentalness': 0.000111,
#   'liveness': 0.344,
#   'valence': 0.151,
#   'tempo': 181.74,
#   'type': 'audio_features',
#   'id': '6c9nkeetGbsoXa7d5E1wHa',
#   'uri': 'spotify:track:6c9nkeetGbsoXa7d5E1wHa',
#   'track_href': 'https://api.spotify.com/v1/tracks/6c9nkeetGbsoXa7d5E1wHa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6c9nkeetGbsoXa7d5E1wHa',
#   'duration_ms': 260227,
#   'time_signature': 4},
#  {'danceability': 0.59,
#   'energy': 0.663,
#   'key': 7,
#   'loudness': -9.224,
#   'mode': 1,
#   'speechiness': 0.0315,
#   'acousticness': 0.141,
#   'instrumentalness': 0,
#   'liveness': 0.0935,
#   'valence': 0.639,
#   'tempo': 113.443,
#   'type': 'audio_features',
#   'id': '5zNf8MI40Us66R3zutaxvt',
#   'uri': 'spotify:track:5zNf8MI40Us66R3zutaxvt',
#   'track_href': 'https://api.spotify.com/v1/tracks/5zNf8MI40Us66R3zutaxvt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5zNf8MI40Us66R3zutaxvt',
#   'duration_ms': 225840,
#   'time_signature': 4},
#  {'danceability': 0.572,
#   'energy': 0.721,
#   'key': 5,
#   'loudness': -8.959,
#   'mode': 1,
#   'speechiness': 0.0402,
#   'acousticness': 0.187,
#   'instrumentalness': 7.41e-06,
#   'liveness': 0.216,
#   'valence': 0.844,
#   'tempo': 164.252,
#   'type': 'audio_features',
#   'id': '05fHQeRbCSjKVS6z0WbQKJ',
#   'uri': 'spotify:track:05fHQeRbCSjKVS6z0WbQKJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/05fHQeRbCSjKVS6z0WbQKJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/05fHQeRbCSjKVS6z0WbQKJ',
#   'duration_ms': 267000,
#   'time_signature': 4},
#  {'danceability': 0.608,
#   'energy': 0.864,
#   'key': 8,
#   'loudness': -7.101,
#   'mode': 1,
#   'speechiness': 0.0522,
#   'acousticness': 0.0444,
#   'instrumentalness': 3.49e-06,
#   'liveness': 0.0341,
#   'valence': 0.947,
#   'tempo': 131.199,
#   'type': 'audio_features',
#   'id': '1GVnAD8Iz45rux6EC657Yv',
#   'uri': 'spotify:track:1GVnAD8Iz45rux6EC657Yv',
#   'track_href': 'https://api.spotify.com/v1/tracks/1GVnAD8Iz45rux6EC657Yv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1GVnAD8Iz45rux6EC657Yv',
#   'duration_ms': 167960,
#   'time_signature': 4},
#  {'danceability': 0.855,
#   'energy': 0.482,
#   'key': 1,
#   'loudness': -8.902,
#   'mode': 1,
#   'speechiness': 0.0576,
#   'acousticness': 0.252,
#   'instrumentalness': 2.2e-05,
#   'liveness': 0.151,
#   'valence': 0.795,
#   'tempo': 97.792,
#   'type': 'audio_features',
#   'id': '3ErsOxqe2RmXkR65wkygDz',
#   'uri': 'spotify:track:3ErsOxqe2RmXkR65wkygDz',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ErsOxqe2RmXkR65wkygDz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ErsOxqe2RmXkR65wkygDz',
#   'duration_ms': 230240,
#   'time_signature': 4},
#  {'danceability': 0.577,
#   'energy': 0.749,
#   'key': 5,
#   'loudness': -7.215,
#   'mode': 0,
#   'speechiness': 0.0279,
#   'acousticness': 0.599,
#   'instrumentalness': 0.0115,
#   'liveness': 0.183,
#   'valence': 0.255,
#   'tempo': 130.97,
#   'type': 'audio_features',
#   'id': '0BCPKOYdS2jbQ8iyB56Zns',
#   'uri': 'spotify:track:0BCPKOYdS2jbQ8iyB56Zns',
#   'track_href': 'https://api.spotify.com/v1/tracks/0BCPKOYdS2jbQ8iyB56Zns',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0BCPKOYdS2jbQ8iyB56Zns',
#   'duration_ms': 307880,
#   'time_signature': 4},
#  {'danceability': 0.638,
#   'energy': 0.352,
#   'key': 10,
#   'loudness': -9.266,
#   'mode': 1,
#   'speechiness': 0.0268,
#   'acousticness': 0.492,
#   'instrumentalness': 0,
#   'liveness': 0.105,
#   'valence': 0.204,
#   'tempo': 94.173,
#   'type': 'audio_features',
#   'id': '7DFawVSjI88xR9mjnWwURg',
#   'uri': 'spotify:track:7DFawVSjI88xR9mjnWwURg',
#   'track_href': 'https://api.spotify.com/v1/tracks/7DFawVSjI88xR9mjnWwURg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7DFawVSjI88xR9mjnWwURg',
#   'duration_ms': 204000,
#   'time_signature': 3},
#  {'danceability': 0.429,
#   'energy': 0.661,
#   'key': 11,
#   'loudness': -7.227,
#   'mode': 1,
#   'speechiness': 0.0281,
#   'acousticness': 0.00239,
#   'instrumentalness': 0.000121,
#   'liveness': 0.234,
#   'valence': 0.285,
#   'tempo': 173.372,
#   'type': 'audio_features',
#   'id': '3AJwUDP919kvQ9QcozQPxg',
#   'uri': 'spotify:track:3AJwUDP919kvQ9QcozQPxg',
#   'track_href': 'https://api.spotify.com/v1/tracks/3AJwUDP919kvQ9QcozQPxg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3AJwUDP919kvQ9QcozQPxg',
#   'duration_ms': 266773,
#   'time_signature': 4},
#  {'danceability': 0.482,
#   'energy': 0.472,
#   'key': 4,
#   'loudness': -5.802,
#   'mode': 1,
#   'speechiness': 0.0336,
#   'acousticness': 0.261,
#   'instrumentalness': 5.08e-05,
#   'liveness': 0.17,
#   'valence': 0.299,
#   'tempo': 138.705,
#   'type': 'audio_features',
#   'id': '5ujavRJ7Mdjg8IEUoWlLCo',
#   'uri': 'spotify:track:5ujavRJ7Mdjg8IEUoWlLCo',
#   'track_href': 'https://api.spotify.com/v1/tracks/5ujavRJ7Mdjg8IEUoWlLCo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ujavRJ7Mdjg8IEUoWlLCo',
#   'duration_ms': 300827,
#   'time_signature': 4},
#  {'danceability': 0.389,
#   'energy': 0.767,
#   'key': 2,
#   'loudness': -4.314,
#   'mode': 1,
#   'speechiness': 0.149,
#   'acousticness': 0.00127,
#   'instrumentalness': 0,
#   'liveness': 0.435,
#   'valence': 0.544,
#   'tempo': 184.926,
#   'type': 'audio_features',
#   'id': '0SLOiJClXkAZluClYpke95',
#   'uri': 'spotify:track:0SLOiJClXkAZluClYpke95',
#   'track_href': 'https://api.spotify.com/v1/tracks/0SLOiJClXkAZluClYpke95',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0SLOiJClXkAZluClYpke95',
#   'duration_ms': 196760,
#   'time_signature': 4},
#  {'danceability': 0.616,
#   'energy': 0.636,
#   'key': 1,
#   'loudness': -7.055,
#   'mode': 1,
#   'speechiness': 0.0325,
#   'acousticness': 0.208,
#   'instrumentalness': 0,
#   'liveness': 0.517,
#   'valence': 0.654,
#   'tempo': 110.618,
#   'type': 'audio_features',
#   'id': '1tdltVUBkiBCW1C3yB4zyD',
#   'uri': 'spotify:track:1tdltVUBkiBCW1C3yB4zyD',
#   'track_href': 'https://api.spotify.com/v1/tracks/1tdltVUBkiBCW1C3yB4zyD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1tdltVUBkiBCW1C3yB4zyD',
#   'duration_ms': 159160,
#   'time_signature': 4},
#  {'danceability': 0.64,
#   'energy': 0.663,
#   'key': 0,
#   'loudness': -7.516,
#   'mode': 1,
#   'speechiness': 0.0374,
#   'acousticness': 0.201,
#   'instrumentalness': 0.00806,
#   'liveness': 0.152,
#   'valence': 0.663,
#   'tempo': 132.77,
#   'type': 'audio_features',
#   'id': '4BP3uh0hFLFRb5cjsgLqDh',
#   'uri': 'spotify:track:4BP3uh0hFLFRb5cjsgLqDh',
#   'track_href': 'https://api.spotify.com/v1/tracks/4BP3uh0hFLFRb5cjsgLqDh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4BP3uh0hFLFRb5cjsgLqDh',
#   'duration_ms': 140773,
#   'time_signature': 4},
#  {'danceability': 0.508,
#   'energy': 0.774,
#   'key': 2,
#   'loudness': -5.973,
#   'mode': 1,
#   'speechiness': 0.0321,
#   'acousticness': 0.0586,
#   'instrumentalness': 4.87e-06,
#   'liveness': 0.063,
#   'valence': 0.942,
#   'tempo': 178.946,
#   'type': 'audio_features',
#   'id': '20OFwXhEXf12DzwXmaV7fj',
#   'uri': 'spotify:track:20OFwXhEXf12DzwXmaV7fj',
#   'track_href': 'https://api.spotify.com/v1/tracks/20OFwXhEXf12DzwXmaV7fj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/20OFwXhEXf12DzwXmaV7fj',
#   'duration_ms': 141600,
#   'time_signature': 4},
#  {'danceability': 0.743,
#   'energy': 0.47,
#   'key': 0,
#   'loudness': -13.154,
#   'mode': 1,
#   'speechiness': 0.029,
#   'acousticness': 0.0936,
#   'instrumentalness': 3.15e-05,
#   'liveness': 0.186,
#   'valence': 0.89,
#   'tempo': 116.122,
#   'type': 'audio_features',
#   'id': '5DnT9a5IM3eMjKgXTWVJvi',
#   'uri': 'spotify:track:5DnT9a5IM3eMjKgXTWVJvi',
#   'track_href': 'https://api.spotify.com/v1/tracks/5DnT9a5IM3eMjKgXTWVJvi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5DnT9a5IM3eMjKgXTWVJvi',
#   'duration_ms': 160333,
#   'time_signature': 4},
#  {'danceability': 0.745,
#   'energy': 0.656,
#   'key': 10,
#   'loudness': -6.393,
#   'mode': 1,
#   'speechiness': 0.0405,
#   'acousticness': 0.188,
#   'instrumentalness': 0.00337,
#   'liveness': 0.0941,
#   'valence': 0.858,
#   'tempo': 105.318,
#   'type': 'audio_features',
#   'id': '3RTUfvRgq3pYTf7XY0FIcS',
#   'uri': 'spotify:track:3RTUfvRgq3pYTf7XY0FIcS',
#   'track_href': 'https://api.spotify.com/v1/tracks/3RTUfvRgq3pYTf7XY0FIcS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3RTUfvRgq3pYTf7XY0FIcS',
#   'duration_ms': 152453,
#   'time_signature': 4},
#  {'danceability': 0.678,
#   'energy': 0.386,
#   'key': 9,
#   'loudness': -15.991,
#   'mode': 1,
#   'speechiness': 0.0464,
#   'acousticness': 0.0686,
#   'instrumentalness': 0.109,
#   'liveness': 0.108,
#   'valence': 0.552,
#   'tempo': 117.303,
#   'type': 'audio_features',
#   'id': '5bUlFE9dGh7pX93PUEVAue',
#   'uri': 'spotify:track:5bUlFE9dGh7pX93PUEVAue',
#   'track_href': 'https://api.spotify.com/v1/tracks/5bUlFE9dGh7pX93PUEVAue',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5bUlFE9dGh7pX93PUEVAue',
#   'duration_ms': 314667,
#   'time_signature': 4},
#  {'danceability': 0.631,
#   'energy': 0.793,
#   'key': 1,
#   'loudness': -4.086,
#   'mode': 0,
#   'speechiness': 0.0468,
#   'acousticness': 0.000218,
#   'instrumentalness': 5.65e-05,
#   'liveness': 0.0976,
#   'valence': 0.648,
#   'tempo': 136.96,
#   'type': 'audio_features',
#   'id': '4m9NfjevXsDVaLtM1kj0Sx',
#   'uri': 'spotify:track:4m9NfjevXsDVaLtM1kj0Sx',
#   'track_href': 'https://api.spotify.com/v1/tracks/4m9NfjevXsDVaLtM1kj0Sx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4m9NfjevXsDVaLtM1kj0Sx',
#   'duration_ms': 189373,
#   'time_signature': 4},
#  {'danceability': 0.775,
#   'energy': 0.866,
#   'key': 9,
#   'loudness': -3.598,
#   'mode': 1,
#   'speechiness': 0.0295,
#   'acousticness': 0.135,
#   'instrumentalness': 0.0376,
#   'liveness': 0.152,
#   'valence': 0.875,
#   'tempo': 131.338,
#   'type': 'audio_features',
#   'id': '15ob9SMGLWrexuPuyuMjKl',
#   'uri': 'spotify:track:15ob9SMGLWrexuPuyuMjKl',
#   'track_href': 'https://api.spotify.com/v1/tracks/15ob9SMGLWrexuPuyuMjKl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/15ob9SMGLWrexuPuyuMjKl',
#   'duration_ms': 295067,
#   'time_signature': 4},
#  {'danceability': 0.418,
#   'energy': 0.452,
#   'key': 1,
#   'loudness': -13.099,
#   'mode': 1,
#   'speechiness': 0.0355,
#   'acousticness': 0.638,
#   'instrumentalness': 0.000252,
#   'liveness': 0.0959,
#   'valence': 0.168,
#   'tempo': 175.124,
#   'type': 'audio_features',
#   'id': '54b8qPFqYqIndfdxiLApea',
#   'uri': 'spotify:track:54b8qPFqYqIndfdxiLApea',
#   'track_href': 'https://api.spotify.com/v1/tracks/54b8qPFqYqIndfdxiLApea',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/54b8qPFqYqIndfdxiLApea',
#   'duration_ms': 218733,
#   'time_signature': 4},
#  {'danceability': 0.548,
#   'energy': 0.691,
#   'key': 4,
#   'loudness': -13.553,
#   'mode': 0,
#   'speechiness': 0.0369,
#   'acousticness': 0.015,
#   'instrumentalness': 0.106,
#   'liveness': 0.144,
#   'valence': 0.667,
#   'tempo': 137.145,
#   'type': 'audio_features',
#   'id': '4KfSdst7rW39C0sfhArdrz',
#   'uri': 'spotify:track:4KfSdst7rW39C0sfhArdrz',
#   'track_href': 'https://api.spotify.com/v1/tracks/4KfSdst7rW39C0sfhArdrz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4KfSdst7rW39C0sfhArdrz',
#   'duration_ms': 261933,
#   'time_signature': 4},
#  {'danceability': 0.435,
#   'energy': 0.459,
#   'key': 9,
#   'loudness': -12.442,
#   'mode': 0,
#   'speechiness': 0.0329,
#   'acousticness': 0.117,
#   'instrumentalness': 0.000103,
#   'liveness': 0.132,
#   'valence': 0.383,
#   'tempo': 129.929,
#   'type': 'audio_features',
#   'id': '5zH710lFSLtkHbMkslLDjR',
#   'uri': 'spotify:track:5zH710lFSLtkHbMkslLDjR',
#   'track_href': 'https://api.spotify.com/v1/tracks/5zH710lFSLtkHbMkslLDjR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5zH710lFSLtkHbMkslLDjR',
#   'duration_ms': 293440,
#   'time_signature': 4},
#  {'danceability': 0.534,
#   'energy': 0.532,
#   'key': 11,
#   'loudness': -9.865,
#   'mode': 1,
#   'speechiness': 0.0292,
#   'acousticness': 0.509,
#   'instrumentalness': 0,
#   'liveness': 0.0868,
#   'valence': 0.3,
#   'tempo': 79.103,
#   'type': 'audio_features',
#   'id': '22wWxHGHRH8gZXNDXRgSqY',
#   'uri': 'spotify:track:22wWxHGHRH8gZXNDXRgSqY',
#   'track_href': 'https://api.spotify.com/v1/tracks/22wWxHGHRH8gZXNDXRgSqY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/22wWxHGHRH8gZXNDXRgSqY',
#   'duration_ms': 254476,
#   'time_signature': 4},
#  {'danceability': 0.626,
#   'energy': 0.746,
#   'key': 7,
#   'loudness': -8.832,
#   'mode': 1,
#   'speechiness': 0.0282,
#   'acousticness': 0.16,
#   'instrumentalness': 0,
#   'liveness': 0.0618,
#   'valence': 0.8,
#   'tempo': 102.896,
#   'type': 'audio_features',
#   'id': '5YjKdeES9QRJ8NmF4Xc8pV',
#   'uri': 'spotify:track:5YjKdeES9QRJ8NmF4Xc8pV',
#   'track_href': 'https://api.spotify.com/v1/tracks/5YjKdeES9QRJ8NmF4Xc8pV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5YjKdeES9QRJ8NmF4Xc8pV',
#   'duration_ms': 310893,
#   'time_signature': 4},
#  {'danceability': 0.427,
#   'energy': 0.626,
#   'key': 8,
#   'loudness': -11.821,
#   'mode': 1,
#   'speechiness': 0.0385,
#   'acousticness': 0.0274,
#   'instrumentalness': 0.00395,
#   'liveness': 0.106,
#   'valence': 0.743,
#   'tempo': 126.877,
#   'type': 'audio_features',
#   'id': '1a2iF9XymafjRk56q7oCxo',
#   'uri': 'spotify:track:1a2iF9XymafjRk56q7oCxo',
#   'track_href': 'https://api.spotify.com/v1/tracks/1a2iF9XymafjRk56q7oCxo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1a2iF9XymafjRk56q7oCxo',
#   'duration_ms': 219587,
#   'time_signature': 4},
#  {'danceability': 0.477,
#   'energy': 0.715,
#   'key': 8,
#   'loudness': -7.81,
#   'mode': 1,
#   'speechiness': 0.0329,
#   'acousticness': 0.037,
#   'instrumentalness': 0.00852,
#   'liveness': 0.0991,
#   'valence': 0.891,
#   'tempo': 116.102,
#   'type': 'audio_features',
#   'id': '5bAOP88AnFD11mTj0HisF2',
#   'uri': 'spotify:track:5bAOP88AnFD11mTj0HisF2',
#   'track_href': 'https://api.spotify.com/v1/tracks/5bAOP88AnFD11mTj0HisF2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5bAOP88AnFD11mTj0HisF2',
#   'duration_ms': 249893,
#   'time_signature': 4},
#  {'danceability': 0.606,
#   'energy': 0.942,
#   'key': 2,
#   'loudness': -3.618,
#   'mode': 1,
#   'speechiness': 0.0357,
#   'acousticness': 0.000233,
#   'instrumentalness': 7.07e-06,
#   'liveness': 0.106,
#   'valence': 0.373,
#   'tempo': 110.98,
#   'type': 'audio_features',
#   'id': '1mX6SYJ1ZpcoxQUiER8wOI',
#   'uri': 'spotify:track:1mX6SYJ1ZpcoxQUiER8wOI',
#   'track_href': 'https://api.spotify.com/v1/tracks/1mX6SYJ1ZpcoxQUiER8wOI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1mX6SYJ1ZpcoxQUiER8wOI',
#   'duration_ms': 270387,
#   'time_signature': 4},
#  {'danceability': 0.621,
#   'energy': 0.961,
#   'key': 11,
#   'loudness': -3.198,
#   'mode': 0,
#   'speechiness': 0.154,
#   'acousticness': 0.00523,
#   'instrumentalness': 0,
#   'liveness': 0.0854,
#   'valence': 0.449,
#   'tempo': 114.451,
#   'type': 'audio_features',
#   'id': '0a7BloCiNzLDD9qSQHh5m7',
#   'uri': 'spotify:track:0a7BloCiNzLDD9qSQHh5m7',
#   'track_href': 'https://api.spotify.com/v1/tracks/0a7BloCiNzLDD9qSQHh5m7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0a7BloCiNzLDD9qSQHh5m7',
#   'duration_ms': 180267,
#   'time_signature': 4},
#  {'danceability': 0.606,
#   'energy': 0.957,
#   'key': 2,
#   'loudness': -3.404,
#   'mode': 1,
#   'speechiness': 0.0814,
#   'acousticness': 0.00117,
#   'instrumentalness': 0.000295,
#   'liveness': 0.14,
#   'valence': 0.603,
#   'tempo': 105.105,
#   'type': 'audio_features',
#   'id': '305WCRhhS10XUcH6AEwZk6',
#   'uri': 'spotify:track:305WCRhhS10XUcH6AEwZk6',
#   'track_href': 'https://api.spotify.com/v1/tracks/305WCRhhS10XUcH6AEwZk6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/305WCRhhS10XUcH6AEwZk6',
#   'duration_ms': 213800,
#   'time_signature': 4},
#  {'danceability': 0.594,
#   'energy': 0.8,
#   'key': 1,
#   'loudness': -4.907,
#   'mode': 1,
#   'speechiness': 0.0299,
#   'acousticness': 0.000929,
#   'instrumentalness': 0,
#   'liveness': 0.109,
#   'valence': 0.534,
#   'tempo': 110.254,
#   'type': 'audio_features',
#   'id': '15XsaekQbikl8BHW3HXvGf',
#   'uri': 'spotify:track:15XsaekQbikl8BHW3HXvGf',
#   'track_href': 'https://api.spotify.com/v1/tracks/15XsaekQbikl8BHW3HXvGf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/15XsaekQbikl8BHW3HXvGf',
#   'duration_ms': 228320,
#   'time_signature': 4},
#  {'danceability': 0.635,
#   'energy': 0.914,
#   'key': 0,
#   'loudness': -5.631,
#   'mode': 1,
#   'speechiness': 0.111,
#   'acousticness': 0.0597,
#   'instrumentalness': 0,
#   'liveness': 0.601,
#   'valence': 0.922,
#   'tempo': 156.014,
#   'type': 'audio_features',
#   'id': '7tCHpjktA50ihtkLz6bAnn',
#   'uri': 'spotify:track:7tCHpjktA50ihtkLz6bAnn',
#   'track_href': 'https://api.spotify.com/v1/tracks/7tCHpjktA50ihtkLz6bAnn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7tCHpjktA50ihtkLz6bAnn',
#   'duration_ms': 175493,
#   'time_signature': 4},
#  {'danceability': 0.497,
#   'energy': 0.97,
#   'key': 10,
#   'loudness': -4.851,
#   'mode': 0,
#   'speechiness': 0.0836,
#   'acousticness': 9.04e-05,
#   'instrumentalness': 0.000674,
#   'liveness': 0.101,
#   'valence': 0.689,
#   'tempo': 138.081,
#   'type': 'audio_features',
#   'id': '6PwjJ58I4t7Mae9xfZ9l9v',
#   'uri': 'spotify:track:6PwjJ58I4t7Mae9xfZ9l9v',
#   'track_href': 'https://api.spotify.com/v1/tracks/6PwjJ58I4t7Mae9xfZ9l9v',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6PwjJ58I4t7Mae9xfZ9l9v',
#   'duration_ms': 197200,
#   'time_signature': 4},
#  {'danceability': 0.352,
#   'energy': 0.911,
#   'key': 1,
#   'loudness': -5.23,
#   'mode': 1,
#   'speechiness': 0.0747,
#   'acousticness': 0.00121,
#   'instrumentalness': 0,
#   'liveness': 0.0995,
#   'valence': 0.236,
#   'tempo': 148.033,
#   'type': 'audio_features',
#   'id': '003vvx7Niy0yvhvHt4a68B',
#   'uri': 'spotify:track:003vvx7Niy0yvhvHt4a68B',
#   'track_href': 'https://api.spotify.com/v1/tracks/003vvx7Niy0yvhvHt4a68B',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/003vvx7Niy0yvhvHt4a68B',
#   'duration_ms': 222973,
#   'time_signature': 4},
#  {'danceability': 0.481,
#   'energy': 0.645,
#   'key': 10,
#   'loudness': -8.535,
#   'mode': 0,
#   'speechiness': 0.318,
#   'acousticness': 0.0863,
#   'instrumentalness': 6.2e-06,
#   'liveness': 0.332,
#   'valence': 0.612,
#   'tempo': 151.307,
#   'type': 'audio_features',
#   'id': '4jU7NPkz4HVnM4hweqNhI1',
#   'uri': 'spotify:track:4jU7NPkz4HVnM4hweqNhI1',
#   'track_href': 'https://api.spotify.com/v1/tracks/4jU7NPkz4HVnM4hweqNhI1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4jU7NPkz4HVnM4hweqNhI1',
#   'duration_ms': 157560,
#   'time_signature': 4},
#  {'danceability': 0.47,
#   'energy': 0.806,
#   'key': 2,
#   'loudness': -2.92,
#   'mode': 1,
#   'speechiness': 0.0505,
#   'acousticness': 0.000575,
#   'instrumentalness': 0.0564,
#   'liveness': 0.0917,
#   'valence': 0.339,
#   'tempo': 98.046,
#   'type': 'audio_features',
#   'id': '37XsaGX7crh4YJKv6k946u',
#   'uri': 'spotify:track:37XsaGX7crh4YJKv6k946u',
#   'track_href': 'https://api.spotify.com/v1/tracks/37XsaGX7crh4YJKv6k946u',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/37XsaGX7crh4YJKv6k946u',
#   'duration_ms': 160747,
#   'time_signature': 4},
#  {'danceability': 0.368,
#   'energy': 0.769,
#   'key': 4,
#   'loudness': -5.002,
#   'mode': 1,
#   'speechiness': 0.0731,
#   'acousticness': 0.000153,
#   'instrumentalness': 0.919,
#   'liveness': 0.0657,
#   'valence': 0.378,
#   'tempo': 187.239,
#   'type': 'audio_features',
#   'id': '0mjOx4zUlL5t4rF1xnrfvi',
#   'uri': 'spotify:track:0mjOx4zUlL5t4rF1xnrfvi',
#   'track_href': 'https://api.spotify.com/v1/tracks/0mjOx4zUlL5t4rF1xnrfvi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0mjOx4zUlL5t4rF1xnrfvi',
#   'duration_ms': 196804,
#   'time_signature': 4},
#  {'danceability': 0.583,
#   'energy': 0.921,
#   'key': 4,
#   'loudness': -8.383,
#   'mode': 1,
#   'speechiness': 0.0697,
#   'acousticness': 0.00377,
#   'instrumentalness': 0.462,
#   'liveness': 0.226,
#   'valence': 0.222,
#   'tempo': 125.98,
#   'type': 'audio_features',
#   'id': '2PIcAQiSOayFwJrfWc72Qc',
#   'uri': 'spotify:track:2PIcAQiSOayFwJrfWc72Qc',
# ...
#   'mode': 1,
#   'speechiness': 0.0295,
#   'acousticness': 0.386,
#   'instrumentalness': 0,
#   'liveness': 0.104,
#   'valence': 0.426,
#   'tempo': 136.526,
#   'type': 'audio_features',
#   'id': '5K7AMlpc4796JRWXb26nCV',
#   'uri': 'spotify:track:5K7AMlpc4796JRWXb26nCV',
#   'track_href': 'https://api.spotify.com/v1/tracks/5K7AMlpc4796JRWXb26nCV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5K7AMlpc4796JRWXb26nCV',
#   'duration_ms': 266533,
#   'time_signature': 3},
#  {'danceability': 0.382,
#   'energy': 0.416,
#   'key': 0,
#   'loudness': -9.303,
#   'mode': 1,
#   'speechiness': 0.0302,
#   'acousticness': 0.0733,
#   'instrumentalness': 0,
#   'liveness': 0.0719,
#   'valence': 0.125,
#   'tempo': 102.089,
#   'type': 'audio_features',
#   'id': '3TwtrR1yNLY1PMPsrGQpOp',
#   'uri': 'spotify:track:3TwtrR1yNLY1PMPsrGQpOp',
#   'track_href': 'https://api.spotify.com/v1/tracks/3TwtrR1yNLY1PMPsrGQpOp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3TwtrR1yNLY1PMPsrGQpOp',
#   'duration_ms': 221693,
#   'time_signature': 4},
#  {'danceability': 0.459,
#   'energy': 0.83,
#   'key': 2,
#   'loudness': -6.254,
#   'mode': 1,
#   'speechiness': 0.0364,
#   'acousticness': 5.15e-05,
#   'instrumentalness': 0.00014,
#   'liveness': 0.206,
#   'valence': 0.431,
#   'tempo': 155.827,
#   'type': 'audio_features',
#   'id': '1ZozJfi8u9cO2Ob8KwiwNT',
#   'uri': 'spotify:track:1ZozJfi8u9cO2Ob8KwiwNT',
#   'track_href': 'https://api.spotify.com/v1/tracks/1ZozJfi8u9cO2Ob8KwiwNT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1ZozJfi8u9cO2Ob8KwiwNT',
#   'duration_ms': 316733,
#   'time_signature': 4},
#  {'danceability': 0.555,
#   'energy': 0.717,
#   'key': 2,
#   'loudness': -5.114,
#   'mode': 1,
#   'speechiness': 0.0269,
#   'acousticness': 0.0414,
#   'instrumentalness': 0,
#   'liveness': 0.116,
#   'valence': 0.374,
#   'tempo': 112.03,
#   'type': 'audio_features',
#   'id': '2n6FX3Jcg4b4Leoz0GOqBF',
#   'uri': 'spotify:track:2n6FX3Jcg4b4Leoz0GOqBF',
#   'track_href': 'https://api.spotify.com/v1/tracks/2n6FX3Jcg4b4Leoz0GOqBF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2n6FX3Jcg4b4Leoz0GOqBF',
#   'duration_ms': 208507,
#   'time_signature': 4},
#  {'danceability': 0.543,
#   'energy': 0.423,
#   'key': 6,
#   'loudness': -8.797,
#   'mode': 1,
#   'speechiness': 0.0282,
#   'acousticness': 0.295,
#   'instrumentalness': 0.0862,
#   'liveness': 0.152,
#   'valence': 0.355,
#   'tempo': 150.132,
#   'type': 'audio_features',
#   'id': '77YKoNCjP5hWqiXMRG2839',
#   'uri': 'spotify:track:77YKoNCjP5hWqiXMRG2839',
#   'track_href': 'https://api.spotify.com/v1/tracks/77YKoNCjP5hWqiXMRG2839',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/77YKoNCjP5hWqiXMRG2839',
#   'duration_ms': 306040,
#   'time_signature': 4},
#  {'danceability': 0.454,
#   'energy': 0.79,
#   'key': 11,
#   'loudness': -4.361,
#   'mode': 0,
#   'speechiness': 0.0285,
#   'acousticness': 0.00604,
#   'instrumentalness': 3.09e-05,
#   'liveness': 0.225,
#   'valence': 0.362,
#   'tempo': 100.225,
#   'type': 'audio_features',
#   'id': '6B618H5CuCdEzcVs0NKTlt',
#   'uri': 'spotify:track:6B618H5CuCdEzcVs0NKTlt',
#   'track_href': 'https://api.spotify.com/v1/tracks/6B618H5CuCdEzcVs0NKTlt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6B618H5CuCdEzcVs0NKTlt',
#   'duration_ms': 291907,
#   'time_signature': 4},
#  {'danceability': 0.643,
#   'energy': 0.569,
#   'key': 7,
#   'loudness': -7.459,
#   'mode': 1,
#   'speechiness': 0.0276,
#   'acousticness': 0.544,
#   'instrumentalness': 2.17e-05,
#   'liveness': 0.178,
#   'valence': 0.275,
#   'tempo': 120.507,
#   'type': 'audio_features',
#   'id': '2lFlveK1y13WWp3vnQtrr3',
#   'uri': 'spotify:track:2lFlveK1y13WWp3vnQtrr3',
#   'track_href': 'https://api.spotify.com/v1/tracks/2lFlveK1y13WWp3vnQtrr3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2lFlveK1y13WWp3vnQtrr3',
#   'duration_ms': 244600,
#   'time_signature': 4},
#  {'danceability': 0.679,
#   'energy': 0.557,
#   'key': 0,
#   'loudness': -7.423,
#   'mode': 1,
#   'speechiness': 0.0281,
#   'acousticness': 0.0904,
#   'instrumentalness': 0.0324,
#   'liveness': 0.0866,
#   'valence': 0.405,
#   'tempo': 85.152,
#   'type': 'audio_features',
#   'id': '6vUPPEN2V2lZ78b6DyEIjZ',
#   'uri': 'spotify:track:6vUPPEN2V2lZ78b6DyEIjZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6vUPPEN2V2lZ78b6DyEIjZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6vUPPEN2V2lZ78b6DyEIjZ',
#   'duration_ms': 303133,
#   'time_signature': 4},
#  {'danceability': 0.459,
#   'energy': 0.427,
#   'key': 7,
#   'loudness': -7.734,
#   'mode': 1,
#   'speechiness': 0.0267,
#   'acousticness': 0.114,
#   'instrumentalness': 0,
#   'liveness': 0.168,
#   'valence': 0.354,
#   'tempo': 139.902,
#   'type': 'audio_features',
#   'id': '0815caqt2Lytro5EIzMufT',
#   'uri': 'spotify:track:0815caqt2Lytro5EIzMufT',
#   'track_href': 'https://api.spotify.com/v1/tracks/0815caqt2Lytro5EIzMufT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0815caqt2Lytro5EIzMufT',
#   'duration_ms': 195493,
#   'time_signature': 3},
#  {'danceability': 0.384,
#   'energy': 0.433,
#   'key': 11,
#   'loudness': -9.256,
#   'mode': 1,
#   'speechiness': 0.0437,
#   'acousticness': 0.24,
#   'instrumentalness': 7.39e-06,
#   'liveness': 0.11,
#   'valence': 0.429,
#   'tempo': 90.176,
#   'type': 'audio_features',
#   'id': '48iWbsOaBUAGzMdoSmqyg1',
#   'uri': 'spotify:track:48iWbsOaBUAGzMdoSmqyg1',
#   'track_href': 'https://api.spotify.com/v1/tracks/48iWbsOaBUAGzMdoSmqyg1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/48iWbsOaBUAGzMdoSmqyg1',
#   'duration_ms': 325600,
#   'time_signature': 4},
#  {'danceability': 0.439,
#   'energy': 0.434,
#   'key': 7,
#   'loudness': -14.918,
#   'mode': 1,
#   'speechiness': 0.0265,
#   'acousticness': 0.0783,
#   'instrumentalness': 5.18e-05,
#   'liveness': 0.14,
#   'valence': 0.204,
#   'tempo': 94.843,
#   'type': 'audio_features',
#   'id': '0gEyKnHvgkrkBM6fbeHdwK',
#   'uri': 'spotify:track:0gEyKnHvgkrkBM6fbeHdwK',
#   'track_href': 'https://api.spotify.com/v1/tracks/0gEyKnHvgkrkBM6fbeHdwK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0gEyKnHvgkrkBM6fbeHdwK',
#   'duration_ms': 274707,
#   'time_signature': 4},
#  {'danceability': 0.758,
#   'energy': 0.896,
#   'key': 9,
#   'loudness': -3.311,
#   'mode': 1,
#   'speechiness': 0.0501,
#   'acousticness': 0.173,
#   'instrumentalness': 3.18e-05,
#   'liveness': 0.136,
#   'valence': 0.797,
#   'tempo': 94.911,
#   'type': 'audio_features',
#   'id': '460Wn6Dq2uMviG5nPXtPnb',
#   'uri': 'spotify:track:460Wn6Dq2uMviG5nPXtPnb',
#   'track_href': 'https://api.spotify.com/v1/tracks/460Wn6Dq2uMviG5nPXtPnb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/460Wn6Dq2uMviG5nPXtPnb',
#   'duration_ms': 207027,
#   'time_signature': 4},
#  {'danceability': 0.426,
#   'energy': 0.881,
#   'key': 4,
#   'loudness': -4.526,
#   'mode': 1,
#   'speechiness': 0.0404,
#   'acousticness': 0.00573,
#   'instrumentalness': 0.0693,
#   'liveness': 0.389,
#   'valence': 0.259,
#   'tempo': 139.986,
#   'type': 'audio_features',
#   'id': '4x3381mYJqptPqT6OKUfmu',
#   'uri': 'spotify:track:4x3381mYJqptPqT6OKUfmu',
#   'track_href': 'https://api.spotify.com/v1/tracks/4x3381mYJqptPqT6OKUfmu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4x3381mYJqptPqT6OKUfmu',
#   'duration_ms': 247893,
#   'time_signature': 4},
#  {'danceability': 0.626,
#   'energy': 0.731,
#   'key': 7,
#   'loudness': -8.0,
#   'mode': 1,
#   'speechiness': 0.0455,
#   'acousticness': 0.0211,
#   'instrumentalness': 0.00231,
#   'liveness': 0.249,
#   'valence': 0.545,
#   'tempo': 79.971,
#   'type': 'audio_features',
#   'id': '70L4pGAmYv0pTADrgsIxpI',
#   'uri': 'spotify:track:70L4pGAmYv0pTADrgsIxpI',
#   'track_href': 'https://api.spotify.com/v1/tracks/70L4pGAmYv0pTADrgsIxpI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/70L4pGAmYv0pTADrgsIxpI',
#   'duration_ms': 329867,
#   'time_signature': 4},
#  {'danceability': 0.438,
#   'energy': 0.805,
#   'key': 8,
#   'loudness': -6.237,
#   'mode': 1,
#   'speechiness': 0.0624,
#   'acousticness': 0.00255,
#   'instrumentalness': 5.69e-05,
#   'liveness': 0.0842,
#   'valence': 0.564,
#   'tempo': 113.253,
#   'type': 'audio_features',
#   'id': '2aoo2jlRnM3A0NyLQqMN2f',
#   'uri': 'spotify:track:2aoo2jlRnM3A0NyLQqMN2f',
#   'track_href': 'https://api.spotify.com/v1/tracks/2aoo2jlRnM3A0NyLQqMN2f',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2aoo2jlRnM3A0NyLQqMN2f',
#   'duration_ms': 240800,
#   'time_signature': 4},
#  {'danceability': 0.404,
#   'energy': 0.902,
#   'key': 1,
#   'loudness': -3.88,
#   'mode': 1,
#   'speechiness': 0.0665,
#   'acousticness': 0.577,
#   'instrumentalness': 0.297,
#   'liveness': 0.287,
#   'valence': 0.497,
#   'tempo': 115.669,
#   'type': 'audio_features',
#   'id': '2kkvB3RNRzwjFdGhaUA0tz',
#   'uri': 'spotify:track:2kkvB3RNRzwjFdGhaUA0tz',
#   'track_href': 'https://api.spotify.com/v1/tracks/2kkvB3RNRzwjFdGhaUA0tz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2kkvB3RNRzwjFdGhaUA0tz',
#   'duration_ms': 423840,
#   'time_signature': 4},
#  {'danceability': 0.464,
#   'energy': 0.795,
#   'key': 1,
#   'loudness': -9.267,
#   'mode': 1,
#   'speechiness': 0.0926,
#   'acousticness': 0.0493,
#   'instrumentalness': 0.00244,
#   'liveness': 0.399,
#   'valence': 0.612,
#   'tempo': 158.691,
#   'type': 'audio_features',
#   'id': '63T7DJ1AFDD6Bn8VzG6JE8',
#   'uri': 'spotify:track:63T7DJ1AFDD6Bn8VzG6JE8',
#   'track_href': 'https://api.spotify.com/v1/tracks/63T7DJ1AFDD6Bn8VzG6JE8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/63T7DJ1AFDD6Bn8VzG6JE8',
#   'duration_ms': 202267,
#   'time_signature': 4},
#  {'danceability': 0.333,
#   'energy': 0.927,
#   'key': 9,
#   'loudness': -8.55,
#   'mode': 0,
#   'speechiness': 0.0733,
#   'acousticness': 0.0029,
#   'instrumentalness': 0.000208,
#   'liveness': 0.297,
#   'valence': 0.385,
#   'tempo': 141.466,
#   'type': 'audio_features',
#   'id': '5QTxFnGygVM4jFQiBovmRo',
#   'uri': 'spotify:track:5QTxFnGygVM4jFQiBovmRo',
#   'track_href': 'https://api.spotify.com/v1/tracks/5QTxFnGygVM4jFQiBovmRo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5QTxFnGygVM4jFQiBovmRo',
#   'duration_ms': 308120,
#   'time_signature': 4},
#  {'danceability': 0.741,
#   'energy': 0.697,
#   'key': 0,
#   'loudness': -7.028,
#   'mode': 1,
#   'speechiness': 0.0277,
#   'acousticness': 0.0664,
#   'instrumentalness': 2.28e-05,
#   'liveness': 0.133,
#   'valence': 0.774,
#   'tempo': 116.109,
#   'type': 'audio_features',
#   'id': '2LawezPeJhN4AWuSB0GtAU',
#   'uri': 'spotify:track:2LawezPeJhN4AWuSB0GtAU',
#   'track_href': 'https://api.spotify.com/v1/tracks/2LawezPeJhN4AWuSB0GtAU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2LawezPeJhN4AWuSB0GtAU',
#   'duration_ms': 160133,
#   'time_signature': 4},
#  {'danceability': 0.338,
#   'energy': 0.34,
#   'key': 9,
#   'loudness': -12.049,
#   'mode': 0,
#   'speechiness': 0.0339,
#   'acousticness': 0.58,
#   'instrumentalness': 0.0032,
#   'liveness': 0.116,
#   'valence': 0.197,
#   'tempo': 82.433,
#   'type': 'audio_features',
#   'id': '5CQ30WqJwcep0pYcV4AMNc',
#   'uri': 'spotify:track:5CQ30WqJwcep0pYcV4AMNc',
#   'track_href': 'https://api.spotify.com/v1/tracks/5CQ30WqJwcep0pYcV4AMNc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5CQ30WqJwcep0pYcV4AMNc',
#   'duration_ms': 482830,
#   'time_signature': 4},
#  {'danceability': 0.533,
#   'energy': 0.905,
#   'key': 2,
#   'loudness': -5.27,
#   'mode': 1,
#   'speechiness': 0.0754,
#   'acousticness': 0.00876,
#   'instrumentalness': 0.578,
#   'liveness': 0.0698,
#   'valence': 0.486,
#   'tempo': 108.9,
#   'type': 'audio_features',
#   'id': '0wJoRiX5K5BxlqZTolB2LD',
#   'uri': 'spotify:track:0wJoRiX5K5BxlqZTolB2LD',
#   'track_href': 'https://api.spotify.com/v1/tracks/0wJoRiX5K5BxlqZTolB2LD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0wJoRiX5K5BxlqZTolB2LD',
#   'duration_ms': 170813,
#   'time_signature': 4},
#  {'danceability': 0.611,
#   'energy': 0.871,
#   'key': 1,
#   'loudness': -2.965,
#   'mode': 1,
#   'speechiness': 0.0393,
#   'acousticness': 0.0384,
#   'instrumentalness': 1.21e-06,
#   'liveness': 0.0965,
#   'valence': 0.7,
#   'tempo': 103.094,
#   'type': 'audio_features',
#   'id': '6xP5TGWu1GBEHjMBmHRbjT',
#   'uri': 'spotify:track:6xP5TGWu1GBEHjMBmHRbjT',
#   'track_href': 'https://api.spotify.com/v1/tracks/6xP5TGWu1GBEHjMBmHRbjT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6xP5TGWu1GBEHjMBmHRbjT',
#   'duration_ms': 207227,
#   'time_signature': 4},
#  {'danceability': 0.605,
#   'energy': 0.764,
#   'key': 0,
#   'loudness': -5.833,
#   'mode': 1,
#   'speechiness': 0.0395,
#   'acousticness': 0.00588,
#   'instrumentalness': 1.24e-06,
#   'liveness': 0.109,
#   'valence': 0.487,
#   'tempo': 117.293,
#   'type': 'audio_features',
#   'id': '3TW48DvQ7ChwY1Yy1tkMaP',
#   'uri': 'spotify:track:3TW48DvQ7ChwY1Yy1tkMaP',
#   'track_href': 'https://api.spotify.com/v1/tracks/3TW48DvQ7ChwY1Yy1tkMaP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3TW48DvQ7ChwY1Yy1tkMaP',
#   'duration_ms': 266560,
#   'time_signature': 4},
#  {'danceability': 0.32,
#   'energy': 0.88,
#   'key': 2,
#   'loudness': -6.035,
#   'mode': 1,
#   'speechiness': 0.0504,
#   'acousticness': 0.000101,
#   'instrumentalness': 4.31e-06,
#   'liveness': 0.076,
#   'valence': 0.257,
#   'tempo': 146.349,
#   'type': 'audio_features',
#   'id': '2VSbEXqs6NbNiZSTcHlIDR',
#   'uri': 'spotify:track:2VSbEXqs6NbNiZSTcHlIDR',
#   'track_href': 'https://api.spotify.com/v1/tracks/2VSbEXqs6NbNiZSTcHlIDR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2VSbEXqs6NbNiZSTcHlIDR',
#   'duration_ms': 294600,
#   'time_signature': 4},
#  {'danceability': 0.552,
#   'energy': 0.645,
#   'key': 7,
#   'loudness': -6.595,
#   'mode': 1,
#   'speechiness': 0.0268,
#   'acousticness': 0.00187,
#   'instrumentalness': 1.38e-06,
#   'liveness': 0.0424,
#   'valence': 0.588,
#   'tempo': 89.518,
#   'type': 'audio_features',
#   'id': '3mhOmh4tRKsMfnRmgZfeBm',
#   'uri': 'spotify:track:3mhOmh4tRKsMfnRmgZfeBm',
#   'track_href': 'https://api.spotify.com/v1/tracks/3mhOmh4tRKsMfnRmgZfeBm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3mhOmh4tRKsMfnRmgZfeBm',
#   'duration_ms': 299733,
#   'time_signature': 4},
#  {'danceability': 0.507,
#   'energy': 0.71,
#   'key': 5,
#   'loudness': -5.02,
#   'mode': 1,
#   'speechiness': 0.0291,
#   'acousticness': 0.0975,
#   'instrumentalness': 1.08e-05,
#   'liveness': 0.17,
#   'valence': 0.45,
#   'tempo': 134.647,
#   'type': 'audio_features',
#   'id': '14J3PO0VnhtcRa31r7Aj1L',
#   'uri': 'spotify:track:14J3PO0VnhtcRa31r7Aj1L',
#   'track_href': 'https://api.spotify.com/v1/tracks/14J3PO0VnhtcRa31r7Aj1L',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/14J3PO0VnhtcRa31r7Aj1L',
#   'duration_ms': 273573,
#   'time_signature': 4},
#  {'danceability': 0.654,
#   'energy': 0.929,
#   'key': 1,
#   'loudness': -5.906,
#   'mode': 1,
#   'speechiness': 0.0998,
#   'acousticness': 0.0474,
#   'instrumentalness': 0,
#   'liveness': 0.0538,
#   'valence': 0.902,
#   'tempo': 144.769,
#   'type': 'audio_features',
#   'id': '6KTv0Z8BmVqM7DPxbGzpVC',
#   'uri': 'spotify:track:6KTv0Z8BmVqM7DPxbGzpVC',
#   'track_href': 'https://api.spotify.com/v1/tracks/6KTv0Z8BmVqM7DPxbGzpVC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6KTv0Z8BmVqM7DPxbGzpVC',
#   'duration_ms': 168840,
#   'time_signature': 4},
#  {'danceability': 0.294,
#   'energy': 0.745,
#   'key': 5,
#   'loudness': -9.138,
#   'mode': 1,
#   'speechiness': 0.0461,
#   'acousticness': 0.05,
#   'instrumentalness': 0.125,
#   'liveness': 0.676,
#   'valence': 0.347,
#   'tempo': 134.364,
#   'type': 'audio_features',
#   'id': '5Z8EDau8uNcP1E8JvmfkZe',
#   'uri': 'spotify:track:5Z8EDau8uNcP1E8JvmfkZe',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Z8EDau8uNcP1E8JvmfkZe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Z8EDau8uNcP1E8JvmfkZe',
#   'duration_ms': 210107,
#   'time_signature': 4},
#  {'danceability': 0.412,
#   'energy': 0.902,
#   'key': 9,
#   'loudness': -11.6,
#   'mode': 1,
#   'speechiness': 0.405,
#   'acousticness': 0.0484,
#   'instrumentalness': 0.131,
#   'liveness': 0.405,
#   'valence': 0.422,
#   'tempo': 89.74,
#   'type': 'audio_features',
#   'id': '0hCB0YR03f6AmQaHbwWDe8',
#   'uri': 'spotify:track:0hCB0YR03f6AmQaHbwWDe8',
#   'track_href': 'https://api.spotify.com/v1/tracks/0hCB0YR03f6AmQaHbwWDe8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0hCB0YR03f6AmQaHbwWDe8',
#   'duration_ms': 333893,
#   'time_signature': 4},
#  ...]

# %%
len(af_list)
# Out:
# 3461

# %%
# Crear una nueva lista que solo contenga elementos que no son None
filtered_af_list = [item for item in af_list if item is not None]

# Ahora intenta crear el DataFrame con la lista filtrada
df_1 = pd.DataFrame(filtered_af_list)

# %%
df_1
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.559   0.345    4   -13.496     1       0.0459      0.057600
# 1            0.663   0.706    1    -4.972     0       0.0383      0.065400
# 2            0.633   0.976    8    -5.362     1       0.0519      0.002810
# 3            0.749   0.745    2   -10.625     1       0.1640      0.000501
# 4            0.356   0.872    2    -7.837     1       0.0680      0.004170
# ...            ...     ...  ...       ...   ...          ...           ...
# 3455         0.454   0.948    5    -4.126     1       0.0832      0.014200
# 3456         0.560   0.742    8    -5.280     1       0.0301      0.017100
# 3457         0.817   0.943    7    -5.037     0       0.0436      0.106000
# 3458         0.472   0.752    0    -6.051     1       0.0555      0.000164
# 3459         0.762   0.800   11    -3.492     0       0.0762      0.283000
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000105    0.1410    0.458   84.581  audio_features
# 1             0.000000    0.1150    0.474  122.013  audio_features
# 2             0.000013    0.3820    0.493  142.027  audio_features
# 3             0.004030    0.3330    0.481  101.972  audio_features
# 4             0.009750    0.0997    0.607  166.300  audio_features
# ...                ...       ...      ...      ...             ...
# 3455          0.000000    0.3460    0.488  149.087  audio_features
# 3456          0.000000    0.1780    0.387  125.027  audio_features
# 3457          0.000371    0.0585    0.946  105.823  audio_features
# 3458          0.181000    0.0903    0.305  133.248  audio_features
# 3459          0.001620    0.0290    0.886  102.999  audio_features
#
#                           id                                   uri  \
# 0     3d9DChrdc6BOeFsbrZ3Is0  spotify:track:3d9DChrdc6BOeFsbrZ3Is0
# 1     6sy3LkhNFjJWlaeSMNwQ62  spotify:track:6sy3LkhNFjJWlaeSMNwQ62
# 2     5YJtMNWKe55yr49cyJgxva  spotify:track:5YJtMNWKe55yr49cyJgxva
# 3     27AHAtAirQapVldIm4c9ZX  spotify:track:27AHAtAirQapVldIm4c9ZX
# 4     5G1sTBGbZT5o4PNRc75RKI  spotify:track:5G1sTBGbZT5o4PNRc75RKI
# ...                      ...                                   ...
# 3455  4BIWl6xOUupdv3jpWtPSDC  spotify:track:4BIWl6xOUupdv3jpWtPSDC
# 3456  3NaTMzagO4nwJVKL9tXcWm  spotify:track:3NaTMzagO4nwJVKL9tXcWm
# 3457  5sBSotSAMpBlz97tLswT7v  spotify:track:5sBSotSAMpBlz97tLswT7v
# 3458  78YJJJH55MSyk7547100sW  spotify:track:78YJJJH55MSyk7547100sW
# 3459  2wl3O5h3OIFGnFuXoGyrS1  spotify:track:2wl3O5h3OIFGnFuXoGyrS1
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/3d9DChrdc6BO...
# 1     https://api.spotify.com/v1/tracks/6sy3LkhNFjJW...
# 2     https://api.spotify.com/v1/tracks/5YJtMNWKe55y...
# 3     https://api.spotify.com/v1/tracks/27AHAtAirQap...
# 4     https://api.spotify.com/v1/tracks/5G1sTBGbZT5o...
# ...                                                 ...
# 3455  https://api.spotify.com/v1/tracks/4BIWl6xOUupd...
# 3456  https://api.spotify.com/v1/tracks/3NaTMzagO4nw...
# 3457  https://api.spotify.com/v1/tracks/5sBSotSAMpBl...
# 3458  https://api.spotify.com/v1/tracks/78YJJJH55MSy...
# 3459  https://api.spotify.com/v1/tracks/2wl3O5h3OIFG...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/3d9D...       264307
# 1     https://api.spotify.com/v1/audio-analysis/6sy3...       257840
# 2     https://api.spotify.com/v1/audio-analysis/5YJt...       197124
# 3     https://api.spotify.com/v1/audio-analysis/27AH...       195107
# 4     https://api.spotify.com/v1/audio-analysis/5G1s...       193653
# ...                                                 ...          ...
# 3455  https://api.spotify.com/v1/audio-analysis/4BIW...       154133
# 3456  https://api.spotify.com/v1/audio-analysis/3NaT...       239839
# 3457  https://api.spotify.com/v1/audio-analysis/5sBS...       222000
# 3458  https://api.spotify.com/v1/audio-analysis/78YJ...       320107
# 3459  https://api.spotify.com/v1/audio-analysis/2wl3...       234213
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 3455               4
# 3456               4
# 3457               4
# 3458               4
# 3459               4
#
# [3460 rows x 18 columns]

# %%
big_playlist_tracks_2 = get_playlist_tracks("Spotify","1Au73ZbV5JOFaii7ituv36")

# %%
bp_ids_2 = []
for i in big_playlist_tracks_2:
    bp_ids_2.append(i['track']['id'])

# %%
bp_ids_chopped_2 = [bp_ids_2[i:i+chunk_size] for i in range(0,len(bp_ids_2), 100)]

# %%
len(big_playlist_tracks_2)
# Out:
# 484

# %%
len(bp_ids_chopped_2)
# Out:
# 5

# %%
af_list_2 = []

for i in bp_ids_chopped_2:
    af_list_2.extend(sp.audio_features(i))

# %%
# Crear una nueva lista que solo contenga elementos que no son None
filtered_af_list_2 = [item for item in af_list_2 if item is not None]

# Ahora intenta crear el DataFrame con la lista filtrada
df_2 = pd.DataFrame(filtered_af_list_2)

# %%
df_2
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.707   0.888    8    -8.157     1       0.0471        0.3600
# 1           0.651   0.732    3    -6.006     0       0.0370        0.1870
# 2           0.859   0.522   11    -9.523     1       0.0547        0.0527
# 3           0.626   0.709   11    -6.201     0       0.0592        0.6990
# 4           0.608   0.386    0    -6.784     1       0.0300        0.7380
# ..            ...     ...  ...       ...   ...          ...           ...
# 478         0.685   0.285    5   -14.348     1       0.0464        0.8110
# 479         0.527   0.157    9    -9.749     0       0.0439        0.8600
# 480         0.504   0.916    7    -3.888     1       0.0512        0.3160
# 481         0.902   0.816    0    -3.077     0       0.0312        0.1240
# 482         0.320   0.588   11    -5.490     0       0.0449        0.3400
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.756000    0.1580    0.765   91.332  audio_features
# 1            0.140000    0.0478    0.694  159.924  audio_features
# 2            0.328000    0.1130    0.388   99.021  audio_features
# 3            0.000120    0.1370    0.933   96.170  audio_features
# 4            0.000000    0.0622    0.611   70.256  audio_features
# ..                ...       ...      ...      ...             ...
# 478          0.000014    0.0803    0.659  105.073  audio_features
# 479          0.000026    0.1110    0.241   86.092  audio_features
# 480          0.000000    0.1850    0.613  127.830  audio_features
# 481          0.000009    0.1800    0.894   96.010  audio_features
# 482          0.000000    0.1120    0.111  131.585  audio_features
#
#                          id                                   uri  \
# 0    36573bwqNlXfYksha3cVRP  spotify:track:36573bwqNlXfYksha3cVRP
# 1    0p8LlXT1FG9vnrCH70dbuo  spotify:track:0p8LlXT1FG9vnrCH70dbuo
# 2    771004k8v5YM4lWeXpiTdP  spotify:track:771004k8v5YM4lWeXpiTdP
# 3    5Y7FsM4jpO5xwNigwWZ9rP  spotify:track:5Y7FsM4jpO5xwNigwWZ9rP
# 4    6LryRmHPjkdq3hRNAdO9KB  spotify:track:6LryRmHPjkdq3hRNAdO9KB
# ..                      ...                                   ...
# 478  0sKymIftfpTNp62P4oTvTY  spotify:track:0sKymIftfpTNp62P4oTvTY
# 479  540A2oZpEHjdMpCSBhF0xx  spotify:track:540A2oZpEHjdMpCSBhF0xx
# 480  0bJsijV1n7s0a62xuCMlsD  spotify:track:0bJsijV1n7s0a62xuCMlsD
# 481  0SGojwNP2zUrgDyeoBQxYO  spotify:track:0SGojwNP2zUrgDyeoBQxYO
# 482  7rc6L3UtM0uvwfpsl07GBL  spotify:track:7rc6L3UtM0uvwfpsl07GBL
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/36573bwqNlXf...
# 1    https://api.spotify.com/v1/tracks/0p8LlXT1FG9v...
# 2    https://api.spotify.com/v1/tracks/771004k8v5YM...
# 3    https://api.spotify.com/v1/tracks/5Y7FsM4jpO5x...
# 4    https://api.spotify.com/v1/tracks/6LryRmHPjkdq...
# ..                                                 ...
# 478  https://api.spotify.com/v1/tracks/0sKymIftfpTN...
# 479  https://api.spotify.com/v1/tracks/540A2oZpEHjd...
# 480  https://api.spotify.com/v1/tracks/0bJsijV1n7s0...
# 481  https://api.spotify.com/v1/tracks/0SGojwNP2zUr...
# 482  https://api.spotify.com/v1/tracks/7rc6L3UtM0uv...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/3657...       245280
# 1    https://api.spotify.com/v1/audio-analysis/0p8L...       312915
# 2    https://api.spotify.com/v1/audio-analysis/7710...       419600
# 3    https://api.spotify.com/v1/audio-analysis/5Y7F...       323800
# 4    https://api.spotify.com/v1/audio-analysis/6Lry...       143587
# ..                                                 ...          ...
# 478  https://api.spotify.com/v1/audio-analysis/0sKy...       182857
# 479  https://api.spotify.com/v1/audio-analysis/540A...       171120
# 480  https://api.spotify.com/v1/audio-analysis/0bJs...       298947
# 481  https://api.spotify.com/v1/audio-analysis/0SGo...       160200
# 482  https://api.spotify.com/v1/audio-analysis/7rc6...       230425
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 478               4
# 479               4
# 480               4
# 481               4
# 482               4
#
# [483 rows x 18 columns]

# %%
# No he corrido el código de acá para abajo...

# %%
big_playlist_tracks_3 = get_playlist_tracks("Spotify","0FfcxKXQuJoMnqYGW0qn7s")
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#
# File /opt/anaconda3/lib/python3.11/http/client.py:1386, in HTTPConnection.getresponse(self)
#    1385 try:
# -> 1386     response.begin()
#    1387 except ConnectionError:
#
# File /opt/anaconda3/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#
# File /opt/anaconda3/lib/python3.11/http/client.py:294, in HTTPResponse._read_status(self)
#     291 if not line:
#     292     # Presumably, the server closed the connection before
#     293     # sending a valid response.
# --> 294     raise RemoteDisconnected("Remote end closed connection without"
#     295                              " response")
#     296 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:845, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     843     new_e = ProtocolError("Connection aborted.", new_e)
# --> 845 retries = retries.increment(
#     846     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     847 )
#     848 retries.sleep()
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/util/retry.py:470, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     469 if read is False or method is None or not self._is_method_retryable(method):
# --> 470     raise reraise(type(error), error, _stacktrace)
#     471 elif read is not None:
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#
# File /opt/anaconda3/lib/python3.11/http/client.py:1386, in HTTPConnection.getresponse(self)
#    1385 try:
# -> 1386     response.begin()
#    1387 except ConnectionError:
#
# File /opt/anaconda3/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#
# File /opt/anaconda3/lib/python3.11/http/client.py:294, in HTTPResponse._read_status(self)
#     291 if not line:
#     292     # Presumably, the server closed the connection before
#     293     # sending a valid response.
# --> 294     raise RemoteDisconnected("Remote end closed connection without"
#     295                              " response")
#     296 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 big_playlist_tracks_3 = get_playlist_tracks("Spotify","0FfcxKXQuJoMnqYGW0qn7s")
#
# Cell In[7], line 2, in get_playlist_tracks(username, playlist_id)
#       1 def get_playlist_tracks(username, playlist_id):
# ----> 2     results = sp.user_playlist_tracks(username,playlist_id,market="GB")
#       3     tracks = results['items']
#       4     while results['next']:
#
# File /opt/anaconda3/lib/python3.11/site-packages/spotipy/client.py:796, in Spotify.user_playlist_tracks(self, user, playlist_id, fields, limit, offset, market)
#     781 warnings.warn(
#     782     "You should use `playlist_tracks(playlist_id)` instead",
#     783     DeprecationWarning,
#     784 )
#     786 """ Get full details of the tracks of a playlist owned by a user.
#     787
#     788     Parameters:
#    (...)
#     794         - market - an ISO 3166-1 alpha-2 country code.
#     795 """
# --> 796 return self.playlist_tracks(
#     797     playlist_id,
#     798     limit=limit,
#     799     offset=offset,
#     800     fields=fields,
#     801     market=market,
#     802 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/spotipy/client.py:698, in Spotify.playlist_tracks(self, playlist_id, fields, limit, offset, market, additional_types)
#     682 """ Get full details of the tracks of a playlist.
#     683
#     684     Parameters:
#    (...)
#     691                              valid types are: track and episode
#     692 """
#     693 warnings.warn(
#     694     "You should use `playlist_items(playlist_id, ...,"
#     695     "additional_types=('track',))` instead",
#     696     DeprecationWarning,
#     697 )
# --> 698 return self.playlist_items(playlist_id, fields, limit, offset,
#     699                            market, additional_types)
#
# File /opt/anaconda3/lib/python3.11/site-packages/spotipy/client.py:722, in Spotify.playlist_items(self, playlist_id, fields, limit, offset, market, additional_types)
#     710 """ Get full details of the tracks and episodes of a playlist.
#     711
#     712     Parameters:
#    (...)
#     719                              valid types are: track and episode
#     720 """
#     721 plid = self._get_id("playlist", playlist_id)
# --> 722 return self._get(
#     723     f"playlists/{plid}/tracks",
#     724     limit=limit,
#     725     offset=offset,
#     726     fields=fields,
#     727     market=market,
#     728     additional_types=",".join(additional_types)
#     729 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/spotipy/client.py:327, in Spotify._get(self, url, args, payload, **kwargs)
#     324 if args:
#     325     kwargs.update(args)
# --> 327 return self._internal_call("GET", url, payload, kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/spotipy/client.py:270, in Spotify._internal_call(self, method, url, payload, params)
#     266 logger.debug('Sending %s to %s with Params: %s Headers: %s and Body: %r ',
#     267              method, url, args.get("params"), headers, args.get('data'))
#     269 try:
# --> 270     response = self._session.request(
#     271         method, url, headers=headers, proxies=self.proxies,
#     272         timeout=self.requests_timeout, **args
#     273     )
#     275     response.raise_for_status()
#     276     results = response.json()
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/adapters.py:501, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#    (...)
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
# --> 501     raise ConnectionError(err, request=request)
#     503 except MaxRetryError as e:
#     504     if isinstance(e.reason, ConnectTimeoutError):
#     505         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
bp_ids_3 = []
for i in big_playlist_tracks_3:
    bp_ids_3.append(i['track']['id'])

# %%
bp_ids_chopped_3 = [bp_ids_3[i:i+chunk_size] for i in range(0,len(bp_ids_3), 100)]

# %%
len(big_playlist_tracks_3)

# %%
len(bp_ids_chopped_3)
# Out:
# 5

# %%
af_list_3 = []

for i in bp_ids_chopped_3:
    af_list_3.extend(sp.audio_features(i))

# %%
# Crear una nueva lista que solo contenga elementos que no son None
filtered_af_list_3 = [item for item in af_list_3 if item is not None]

# Ahora intenta crear el DataFrame con la lista filtrada
df_3 = pd.DataFrame(filtered_af_list_3)

# %%
df_3
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.707   0.888    8    -8.157     1       0.0471        0.3600
# 1           0.651   0.732    3    -6.006     0       0.0370        0.1870
# 2           0.859   0.522   11    -9.523     1       0.0547        0.0527
# 3           0.626   0.709   11    -6.201     0       0.0592        0.6990
# 4           0.608   0.386    0    -6.784     1       0.0300        0.7380
# ..            ...     ...  ...       ...   ...          ...           ...
# 478         0.685   0.285    5   -14.348     1       0.0464        0.8110
# 479         0.527   0.157    9    -9.749     0       0.0439        0.8600
# 480         0.504   0.916    7    -3.888     1       0.0512        0.3160
# 481         0.902   0.816    0    -3.077     0       0.0312        0.1240
# 482         0.320   0.588   11    -5.490     0       0.0449        0.3400
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.756000    0.1580    0.765   91.332  audio_features
# 1            0.140000    0.0478    0.694  159.924  audio_features
# 2            0.328000    0.1130    0.388   99.021  audio_features
# 3            0.000120    0.1370    0.933   96.170  audio_features
# 4            0.000000    0.0622    0.611   70.256  audio_features
# ..                ...       ...      ...      ...             ...
# 478          0.000014    0.0803    0.659  105.073  audio_features
# 479          0.000026    0.1110    0.241   86.092  audio_features
# 480          0.000000    0.1850    0.613  127.830  audio_features
# 481          0.000009    0.1800    0.894   96.010  audio_features
# 482          0.000000    0.1120    0.111  131.585  audio_features
#
#                          id                                   uri  \
# 0    36573bwqNlXfYksha3cVRP  spotify:track:36573bwqNlXfYksha3cVRP
# 1    0p8LlXT1FG9vnrCH70dbuo  spotify:track:0p8LlXT1FG9vnrCH70dbuo
# 2    771004k8v5YM4lWeXpiTdP  spotify:track:771004k8v5YM4lWeXpiTdP
# 3    5Y7FsM4jpO5xwNigwWZ9rP  spotify:track:5Y7FsM4jpO5xwNigwWZ9rP
# 4    6LryRmHPjkdq3hRNAdO9KB  spotify:track:6LryRmHPjkdq3hRNAdO9KB
# ..                      ...                                   ...
# 478  0sKymIftfpTNp62P4oTvTY  spotify:track:0sKymIftfpTNp62P4oTvTY
# 479  540A2oZpEHjdMpCSBhF0xx  spotify:track:540A2oZpEHjdMpCSBhF0xx
# 480  0bJsijV1n7s0a62xuCMlsD  spotify:track:0bJsijV1n7s0a62xuCMlsD
# 481  0SGojwNP2zUrgDyeoBQxYO  spotify:track:0SGojwNP2zUrgDyeoBQxYO
# 482  7rc6L3UtM0uvwfpsl07GBL  spotify:track:7rc6L3UtM0uvwfpsl07GBL
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/36573bwqNlXf...
# 1    https://api.spotify.com/v1/tracks/0p8LlXT1FG9v...
# 2    https://api.spotify.com/v1/tracks/771004k8v5YM...
# 3    https://api.spotify.com/v1/tracks/5Y7FsM4jpO5x...
# 4    https://api.spotify.com/v1/tracks/6LryRmHPjkdq...
# ..                                                 ...
# 478  https://api.spotify.com/v1/tracks/0sKymIftfpTN...
# 479  https://api.spotify.com/v1/tracks/540A2oZpEHjd...
# 480  https://api.spotify.com/v1/tracks/0bJsijV1n7s0...
# 481  https://api.spotify.com/v1/tracks/0SGojwNP2zUr...
# 482  https://api.spotify.com/v1/tracks/7rc6L3UtM0uv...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/3657...       245280
# 1    https://api.spotify.com/v1/audio-analysis/0p8L...       312915
# 2    https://api.spotify.com/v1/audio-analysis/7710...       419600
# 3    https://api.spotify.com/v1/audio-analysis/5Y7F...       323800
# 4    https://api.spotify.com/v1/audio-analysis/6Lry...       143587
# ..                                                 ...          ...
# 478  https://api.spotify.com/v1/audio-analysis/0sKy...       182857
# 479  https://api.spotify.com/v1/audio-analysis/540A...       171120
# 480  https://api.spotify.com/v1/audio-analysis/0bJs...       298947
# 481  https://api.spotify.com/v1/audio-analysis/0SGo...       160200
# 482  https://api.spotify.com/v1/audio-analysis/7rc6...       230425
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 478               4
# 479               4
# 480               4
# 481               4
# 482               4
#
# [483 rows x 18 columns]

# %%
0FfcxKXQuJoMnqYGW0qn7s

# %%
# df_merged.to_csv("/Users/karollvivianalopezvillegas/GitHub/DA_FT_Extra_Week10/Week_10/Spotify_many_songs.csv", index = False)
